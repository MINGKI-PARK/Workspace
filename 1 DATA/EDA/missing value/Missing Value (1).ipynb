# %%
import numpy as np
import pandas as pd

path = 'c:/reposit/data/'

# %%
df = pd.read_csv(path + 'vizable/슈퍼스토어 - 샘플.xls - 주문.csv')
df.shape
# Out:
# (10933, 20)

# %%
df.isnull().sum()
# Out:
# 행 ID     0
# 주문 ID    0
# 주문 날짜    0
# 배송 날짜    0
# 배송 형태    0
# 고객 ID    0
# 고객 이름    0
# 세그먼트     0
# 도시       0
# 시/도      0
# 국가/지역    0
# 지역       0
# 제품 ID    0
# 범주       0
# 하위 범주    0
# 제품 이름    0
# 매출       0
# 수량       0
# 할인율      0
# 수익       0
# dtype: int64

# %%
df.head(3)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
#
#    Credit amount  Duration    Purpose
# 0           1169         6   radio/TV
# 1           5951        48   radio/TV
# 2           2096        12  education

# %%
df = pd.read_csv(path + 'kaggle/german_credit/german_credit_data.csv', index_col=0)
df.shape
# Out:
# (1000, 9)

# %%
df.isnull().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# dtype: int64

# %%
df.head(3)
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
#
#    Duration    Purpose
# 0         6   radio/TV
# 1        48   radio/TV
# 2        12  education

# %%
for i in range(50):
    df.loc[1000+i] = [np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan]

df.tail(3)
# Out:
#       Age  Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 1047  NaN  NaN  NaN     NaN             NaN              NaN            NaN
# 1048  NaN  NaN  NaN     NaN             NaN              NaN            NaN
# 1049  NaN  NaN  NaN     NaN             NaN              NaN            NaN
#
#       Duration Purpose
# 1047       NaN     NaN
# 1048       NaN     NaN
# 1049       NaN     NaN

# %%
df.isnull().sum()
# Out:
# Age                  50
# Sex                  50
# Job                  50
# Housing              50
# Saving accounts     233
# Checking account    444
# Credit amount        50
# Duration             50
# Purpose              50
# dtype: int64

# %%
df = pd.read_csv(path + 'kaggle/boston-housing/train.csv')
df.shape
# Out:
# (333, 15)

# %%
df.head(3)
# Out:
#    ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   1  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1   2  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2   4  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4

# %%
df.tail(3)
# Out:
#       ID     crim   zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 330  503  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 331  504  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 332  506  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio  black  lstat  medv
# 330     21.0  396.9   9.08  20.6
# 331     21.0  396.9   5.64  23.9
# 332     21.0  396.9   7.88  11.9

# %%
df.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
for i in range(50):
    df.loc[333+i] = [np.nan] * 15

df.tail(3)
# Out:
#      ID  crim  zn  indus  chas  nox  rm  age  dis  rad  tax  ptratio  black  \
# 380 NaN   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN    NaN
# 381 NaN   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN    NaN
# 382 NaN   NaN NaN    NaN   NaN  NaN NaN  NaN  NaN  NaN  NaN      NaN    NaN
#
#      lstat  medv
# 380    NaN   NaN
# 381    NaN   NaN
# 382    NaN   NaN

# %%
df.isna().sum()
# Out:
# ID         50
# crim       50
# zn         50
# indus      50
# chas       50
# nox        50
# rm         50
# age        50
# dis        50
# rad        50
# tax        50
# ptratio    50
# black      50
# lstat      50
# medv       50
# dtype: int64

# %%
df.head(3)
# Out:
#     ID     crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  1.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  2.0  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  4.0  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
#
#    ptratio   black  lstat  medv
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     18.7  394.63   2.94  33.4
