# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#데이터-준비하기" data-toc-modified-id="데이터-준비하기-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>데이터 준비하기</a></span><ul class="toc-item"><li><span><a href="#데이터-합치기" data-toc-modified-id="데이터-합치기-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>데이터 합치기</a></span></li><li><span><a href="#컬럼-삭제" data-toc-modified-id="컬럼-삭제-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>컬럼 삭제</a></span></li><li><span><a href="#사용일시-컬럼을-datatime형식으로-변경하기" data-toc-modified-id="사용일시-컬럼을-datatime형식으로-변경하기-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>사용일시 컬럼을 datatime형식으로 변경하기</a></span></li><li><span><a href="#사용장소별로-이용횟수-확인하기" data-toc-modified-id="사용장소별로-이용횟수-확인하기-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>사용장소별로 이용횟수 확인하기</a></span></li></ul></li><li><span><a href="#사용장소를-기준으로" data-toc-modified-id="사용장소를-기준으로-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>사용장소를 기준으로</a></span><ul class="toc-item"><li><span><a href="#사용장소" data-toc-modified-id="사용장소-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>사용장소</a></span></li></ul></li><li><span><a href="#사용자-컬럼을-기준으로" data-toc-modified-id="사용자-컬럼을-기준으로-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>사용자 컬럼을 기준으로</a></span><ul class="toc-item"><li><span><a href="#사용자" data-toc-modified-id="사용자-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>사용자</a></span></li><li><span><a href="#의장's-pick" data-toc-modified-id="의장's-pick-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>의장's pick</a></span></li><li><span><a href="#부의장's-pick" data-toc-modified-id="부의장's-pick-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>부의장's pick</a></span></li></ul></li><li><span><a href="#사용일시-컬럼을-기준으로" data-toc-modified-id="사용일시-컬럼을-기준으로-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>사용일시 컬럼을 기준으로</a></span><ul class="toc-item"><li><span><a href="#월-컬럼-추가하기" data-toc-modified-id="월-컬럼-추가하기-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>월 컬럼 추가하기</a></span></li><li><span><a href="#월별-금액-살펴보기" data-toc-modified-id="월별-금액-살펴보기-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>월별 금액 살펴보기</a></span></li></ul></li><li><span><a href="#집행대상-칼럼을-기준으로-확인하기" data-toc-modified-id="집행대상-칼럼을-기준으로-확인하기-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>집행대상 칼럼을 기준으로 확인하기</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import folium
from tqdm.notebook import tqdm

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# 한글 폰드 문제 해결
import platform
path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc


if platform.system() == 'Darwin':
    rc('font', family = 'AppleGothic')
elif platform.system() == 'Windows':
        font_name = font_manager.FontProperties(fname=path).get_name()
        rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~')

# %% [markdown]
# ## 데이터 준비하기

# %%
d1 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(1월).xlsx', header=2)
d2 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(2월).xlsx', header=2)
d3 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(3월).xlsx', header=2)
d4 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(4월).xlsx', header=2)
d5 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(5월).xlsx', header=2)
d6 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(6월).xlsx', header=2)
d7 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(7월).xlsx', header=2)
d8 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(8월).xlsx', header=2)
d9 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(9월).xlsx', header=2)
d10 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(10월).xlsx', header=2)
d11 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(11월).xlsx', header=2)
d12 = pd.read_excel('../data/관악구/2019/의장단 업무추진비 집행내역(12월).xlsx', header=2)

# %%
d1
# Out:
#       연번      사용자        사용일시 Unnamed: 3    사용금액     사용장소  \
# 0      1       의장  2019-01-02      08:44   58500      완산정
# 1      2       의장  2019-01-02      12:36   89000    제주은갈치
# 2      3       의장  2019-01-04      12:53   14000     아리차이
# 3      4       의장  2019-01-09      12:33   77000    남원추어탕
# 4      5       의장  2019-01-09      14:48   83300     카페베네
# ..   ...      ...         ...        ...     ...      ...
# 109  110  도시건설위원장  2019-01-24      13:07  120000     만리장성
# 110  111  도시건설위원장  2019-01-25      14:22  280000     감나무집
# 111  112  도시건설위원장  2019-01-26      20:36  200000  전주콩나물국밥
# 112  113  도시건설위원장  2019-01-28      19:16  259000  남도전문음식점
# 113  114  도시건설위원장  2019-01-29      18:07  480000     감나무집
#
#                        주소  사용방법                   사용내역           집행대상
# 0          서울 관악구 봉천로 484  신용카드  의정활동 및 의회운영 관련 업무휴대경비        의장 등 9명
# 1          서울 관악구 관악로 139  신용카드  의정활동 및 의회운영 관련 업무휴대경비        의장 등 7명
# ...

# %%
d2
# Out:
#     연번      사용자        사용일시 Unnamed: 3    사용금액            사용장소  \
# 0    1       의장  2019-02-01      12:34  139000           남원추어탕
# 1    2       의장  2019-02-01      19:36  450000         우리동네고기집
# 2    3       의장  2019-02-08      13:54  192000              정가
# 3    4       의장  2019-02-08      21:42  340000         우리동네고기집
# 4    5       의장  2019-02-11      14:39  102000           제주은갈치
# ..  ..      ...         ...        ...     ...             ...
# 75  76  도시건설위원장  2019-02-20      18:48   60000           최상의우동
# 76  77  도시건설위원장  2019-02-21      19:37  160000          국내산생고기
# 77  78  도시건설위원장  2019-02-22      20:42  142000       삼다돈가(봉천점)
# 78  79  도시건설위원장  2019-02-23      16:10   45200  서울대입구역2호 파리바게뜨
# 79  80  도시건설위원장  2019-02-23      20:11  402000             시골집
#
#                    주소  사용방법                   사용내역           집행대상
# 0     서울 관악구 쑥고개로 135  신용카드  의정활동 및 의회운영 관련 업무유대경비       의장 등 14명
# 1      서울 관악구 인헌6길 24  신용카드  의정활동 및 의회운영 관련 업무유대경비       의장 등 13명
# ...

# %% [markdown]
# ### 데이터 합치기

# %%
data = pd.concat([d1, d2, d3, d4, d5, d6, d7, d8, d9, d10, d11, d12], ignore_index=True)
data
# Out:
#       연번      사용자        사용일시 Unnamed: 3    사용금액      사용장소  \
# 0      1       의장  2019-01-02      08:44   58500       완산정
# 1      2       의장  2019-01-02      12:36   89000     제주은갈치
# 2      3       의장  2019-01-04      12:53   14000      아리차이
# 3      4       의장  2019-01-09      12:33   77000     남원추어탕
# 4      5       의장  2019-01-09      14:48   83300      카페베네
# ...   ..      ...         ...        ...     ...       ...
# 1146  69  보건복지위원장  2019-12-05      18:56   56000      감나무집
# 1147  70  보건복지위원장  2019-12-06      20:04   79600      자연별곡
# 1148  71  보건복지위원장  2019-12-11      21:48   21000      홍콩반점
# 1149  72  보건복지위원장  2019-12-23      12:44   31500  메밀꽃밭언덕너머
# 1150  73  보건복지위원장  2019-12-27      19:08  217200      보현푸드
#
#                         주소  사용방법                   사용내역          집행대상
# 0           서울 관악구 봉천로 484  신용카드  의정활동 및 의회운영 관련 업무휴대경비       의장 등 9명
# 1           서울 관악구 관악로 139  신용카드  의정활동 및 의회운영 관련 업무휴대경비       의장 등 7명
# ...

# %%
data[data['주소'].isnull()]
# Out:
#      연번    사용자        사용일시 Unnamed: 3     사용금액 사용장소   주소 사용방법  \
# 8     9     의장  2019-01-11        NaN    50000  NaN  NaN   현금
# 215  22     의장  2019-03-25        NaN    50000  NaN  NaN   현금
# 370  87  관악구의회  2019-04-26        NaN  1200000  NaN  NaN   현금
# 705  16     의장  2019-08-16        NaN    50000  NaN  NaN   현금
# 907  13     의장  2019-10-18        NaN    50000  NaN  NaN   현금
# 996   2     의장  2019-11-01        NaN    50000  NaN  NaN   현금
#
#                      사용내역              집행대상
# 8            의회운영 경조사비 지출           안OO 주무관
# 215  의장 의회운영업무추진비 경조사비 지출  김OO 주무관 빙부상 경조사금
# 370     강원도 산불 피해지원 성금 납부            재해구호협회
# 705     의장 의회운영업무추진비 경조사비          관악구의회 의원
# 907  의장 의회운영업무추진비 경조사비 지출         사무국 직원 1명
# 996        의회운영업무추진비 경조사비             의원 1명

# %%
data[data['사용방법']=='현금']
# Out:
#      연번    사용자        사용일시 Unnamed: 3     사용금액 사용장소   주소 사용방법  \
# 8     9     의장  2019-01-11        NaN    50000  NaN  NaN   현금
# 215  22     의장  2019-03-25        NaN    50000  NaN  NaN   현금
# 370  87  관악구의회  2019-04-26        NaN  1200000  NaN  NaN   현금
# 705  16     의장  2019-08-16        NaN    50000  NaN  NaN   현금
# 907  13     의장  2019-10-18        NaN    50000  NaN  NaN   현금
# 996   2     의장  2019-11-01        NaN    50000  NaN  NaN   현금
#
#                      사용내역              집행대상
# 8            의회운영 경조사비 지출           안OO 주무관
# 215  의장 의회운영업무추진비 경조사비 지출  김OO 주무관 빙부상 경조사금
# 370     강원도 산불 피해지원 성금 납부            재해구호협회
# 705     의장 의회운영업무추진비 경조사비          관악구의회 의원
# 907  의장 의회운영업무추진비 경조사비 지출         사무국 직원 1명
# 996        의회운영업무추진비 경조사비             의원 1명

# %%
data['사용장소'].sort_values().unique()
# Out:
# array(['#207', '(주)소명생고기', '(주)송원마포갈비', '406CAFE', 'KFC', 'KSNET',
#        'SEROTONIN', '가마솥', '가마솥삼계탕', '가빈', '가야촌오리주물럭', '가야촌유황오리',
#        '가온매운갈비찜', '가츠몽', '감격시대', '감나무집', '값진식육', '강강술래', '강강술래신림본동점',
#        '강남식당', '강촌민물매운탕2호점', '개성보쌈', '갯바위', '갯벌낙지', '거목쟁반짜장', '경복궁',
#        '경식이네알쌈쭈꾸미', '고기만족', '고기킹', '고려왕족발', '고창복의낙지세상', '고향순대국', '고향식당',
#        '고흥식당', '광명수산', '광어삼촌', '교대전집', '교촌치킨', '구름산원주추어탕', '구수옥설렁탕',
#        '국내산생고기', '국회루', '굴러들어온복', '그린파크식당', '금비', '금수강산', '금수사', '기사님식당',
#        '기장산곰장어포차', '김가네', '김가네 관악구청점', '김밥', '김밥천국', '김밥＆백반', '김용해순대국',
#        '김채원24시감자탕', '꽃올림', '꿀벌식당', '나의집', '나주곰탕', '나주오리종가', '낙지마을해물구이',
#        '난곡문성파리바게뜨', '난곡사거리 파리바게뜨', '남궁야', '남도식당', '남도전문음식점', '남도해물요리전문점',
#        '남원추어탕', '낭만모로코', '너구리칼국수', '노가리7080', '농장사람들', '다리목', '다빈',
#        '다온죽카페', '다우데이타', '달구리', '당곡기사식당', '당진강완옥아귀찜', '당진아구동태찜탕',
#        '대가한방오리', '대박수산', '대주직판장', '대호아구집', '더고기서울대맛집', '더진국', '던킨도너츠',
# ...

# %%
data.sort_values(by='사용장소', inplace=True)
data
# Out:
#      연번      사용자        사용일시 Unnamed: 3     사용금액       사용장소  \
# 950  56  행정재경위원장  2019-10-03      14:03    15000       #207
# 757  68  행정재경위원장  2019-08-05      16:06    12200       #207
# 71   72  행정재경위원장  2019-01-03      20:32   100000   (주)소명생고기
# 72   73  행정재경위원장  2019-01-06      18:09    45500  (주)송원마포갈비
# 883  81  도시건설위원장  2019-09-01      19:06     6500    406CAFE
# ..   ..      ...         ...        ...      ...        ...
# 215  22       의장  2019-03-25        NaN    50000        NaN
# 370  87    관악구의회  2019-04-26        NaN  1200000        NaN
# 705  16       의장  2019-08-16        NaN    50000        NaN
# 907  13       의장  2019-10-18        NaN    50000        NaN
# 996   2       의장  2019-11-01        NaN    50000        NaN
#
#                       주소  사용방법                   사용내역              집행대상
# 950       서울 관악구 원신길 128  신용카드  의정활동 및 상임위  관련 업무 간담회       행정재경위원장외 4명
# 757       서울 관악구 원신길 128  신용카드   의정활동 및 상임위 관련 업무 간담회      행정재경위원장 등 4명
# ...

# %% [markdown]
# ### 컬럼 삭제

# %%
# 연번 컬럼 삭제
del data['연번']

# %%
# 시간 삭제
del data['Unnamed: 3']

# %% [markdown]
# ### 사용일시 컬럼을 datatime형식으로 변경하기

# %%
data['사용일시'] = pd.to_datetime(data['사용일시'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1151 entries, 950 to 996
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용자     1151 non-null   object
#  1   사용일시    1151 non-null   datetime64[ns]
#  2   사용금액    1151 non-null   int64
#  3   사용장소    1145 non-null   object
#  4   주소      1145 non-null   object
#  5   사용방법    1151 non-null   object
#  6   사용내역    1151 non-null   object
#  7   집행대상    1151 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 80.9+ KB

# %% [markdown]
# ### 사용장소별로 이용횟수 확인하기

# %%
# len(name_price)

# %%
# for i in range(0,len(name_price)):
#     print(name_price.index[i] + '---->', name_price['횟수'][i])

# %%
# name_price.index[0]
# name_price['횟수'][1]

# %% [markdown]
# ## 사용장소를 기준으로

# %%
# 데이터 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1151 entries, 950 to 996
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용자     1151 non-null   object
#  1   사용일시    1151 non-null   datetime64[ns]
#  2   사용금액    1151 non-null   int64
#  3   사용장소    1145 non-null   object
#  4   주소      1145 non-null   object
#  5   사용방법    1151 non-null   object
#  6   사용내역    1151 non-null   object
#  7   집행대상    1151 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 80.9+ KB

# %%
data
# Out:
#          사용자       사용일시     사용금액       사용장소                   주소  사용방법  \
# 950  행정재경위원장 2019-10-03    15000       #207       서울 관악구 원신길 128  신용카드
# 757  행정재경위원장 2019-08-05    12200       #207       서울 관악구 원신길 128  신용카드
# 71   행정재경위원장 2019-01-03   100000   (주)소명생고기      서울 금천구 시흥대로 264  신용카드
# 72   행정재경위원장 2019-01-06    45500  (주)송원마포갈비  서울 영등포구 도림로147길 2-1  신용카드
# 883  도시건설위원장 2019-09-01     6500    406CAFE    서울 관악구 신림로29길 3-7  신용카드
# ..       ...        ...      ...        ...                  ...   ...
# 215       의장 2019-03-25    50000        NaN                  NaN    현금
# 370    관악구의회 2019-04-26  1200000        NaN                  NaN    현금
# 705       의장 2019-08-16    50000        NaN                  NaN    현금
# 907       의장 2019-10-18    50000        NaN                  NaN    현금
# 996       의장 2019-11-01    50000        NaN                  NaN    현금
#
#                       사용내역              집행대상
# 950  의정활동 및 상임위  관련 업무 간담회       행정재경위원장외 4명
# ...

# %% [markdown]
# ### 사용장소

# %%
name_price = pd.pivot_table(data, index=['사용장소'], aggfunc=np.sum)
name_price.head(30)
# Out:
#                사용금액
# 사용장소
# #207          27200
# (주)소명생고기     100000
# (주)송원마포갈비     45500
# 406CAFE        6500
# KFC           19200
# KSNET         60000
# SEROTONIN     17400
# 가마솥           28000
# 가마솥삼계탕        35000
# 가빈            28500
# 가야촌오리주물럭      41000
# 가야촌유황오리       71000
# 가온매운갈비찜      180000
# 가츠몽           10000
# 감격시대         220000
# 감나무집        6047500
# 값진식육          55900
# 강강술래        2860500
# 강강술래신림본동점    115000
# 강남식당          20000
# 강촌민물매운탕2호점   171000
# 개성보쌈          21000
# 갯바위          265000
# 갯벌낙지         210000
# 거목쟁반짜장       136500
# 경복궁          220000
# 경식이네알쌈쭈꾸미    137000
# 고기만족          46500
# 고기킹          124000
# 고려왕족발        238000

# %%
# 사용금액 높은 순으로 정렬해보기
top20 = name_price.sort_values(by='사용금액', ascending=False).head(20)
top20
# Out:
#              사용금액
# 사용장소
# 제주은갈치     8053000
# 우리동네고기집   7319900
# 옥천골       6801000
# 감나무집      6047500
# 통큰대박집     2985000
# 강강술래      2860500
# 다리목       2760000
# 신바람과일     2730000
# 금비        2590000
# 시골집       2526000
# 떡보의하루     2381600
# 남원추어탕     1943000
# 은성숯불갈비    1867100
# 해물나라      1712000
# 아리차이      1605000
# 그린파크식당    1600000
# 명품횡성한우가   1562000
# 정가        1229000
# 고창복의낙지세상  1183000
# 하이보       1170000

# %%
top20.sort_values(by='사용금액', inplace=True)

# %%
# 그래프 그려보기
plt.figure(figsize=(10,8))
plt.barh(top20.index, top20['사용금액'])
plt.xlabel('사용금액')
plt.grid()
plt.show()

# %%
name_price['사용금액'].sum()
# Out:
# 134107000

# %%
134107000/12
# Out:
# 11175583.333333334

# %%
# 횟수 추가하기
name_price['횟수'] = data['사용장소'].value_counts()

# %%
# 평균 금액 컬럼 추가하기

name_price['평균금액'] = name_price['사용금액'] // name_price['횟수']
name_price.head()
# Out:
#              사용금액  횟수    평균금액
# 사용장소
# #207        27200   2   13600
# (주)소명생고기   100000   1  100000
# (주)송원마포갈비   45500   1   45500
# 406CAFE      6500   1    6500
# KFC         19200   1   19200

# %%
# 횟수 높은 순으로 정렬하기
name_price.sort_values(by='횟수', ascending=False)
# Out:
#              사용금액  횟수    평균금액
# 사용장소
# 제주은갈치     8053000  64  125828
# 옥천골       6801000  40  170025
# 감나무집      6047500  30  201583
# 우리동네고기집   7319900  22  332722
# 생각보다맛있는집  1050000  19   55263
# ...           ...  ..     ...
# 보배곱창       283000   1  283000
# 보글보글지글지글    30000   1   30000
# 병천순대국       21000   1   21000
# 버드나무       111500   1  111500
# 히포커피        10800   1   10800
#
# [432 rows x 3 columns]

# %%
# 횟수 10회 이상만 보기
name10 = name_price[name_price['횟수']>=10].sort_values(by='횟수')
name10
# Out:
#              사용금액  횟수    평균금액
# 사용장소
# 강강술래      2860500  10  286050
# 금비        2590000  10  259000
# 아리차이      1605000  10  160500
# 전진식당       314000  10   31400
# 고창복의낙지세상  1183000  11  107545
# 당곡기사식당     846000  11   76909
# 떡보의하루     2381600  11  216509
# 다리목       2760000  12  230000
# 명품횡성한우가   1562000  12  130166
# 시골집       2526000  12  210500
# 통큰대박집     2985000  13  229615
# 콩심         328000  14   23428
# 만리장성       669000  14   47785
# 해물나라      1712000  15  114133
# 옛날육개장     1057000  16   66062
# 은성숯불갈비    1867100  19   98268
# 생각보다맛있는집  1050000  19   55263
# 남원추어탕     1943000  19  102263
# 우리동네고기집   7319900  22  332722
# 감나무집      6047500  30  201583
# 옥천골       6801000  40  170025
# 제주은갈치     8053000  64  125828

# %%
plt.figure(figsize=(10,8))
plt.barh(name10.index, name10['횟수'])
plt.xlabel('방문횟수')
plt.grid()
plt.show()

# %%
name10['사용금액'].sum()
# Out:
# 58460600

# %%
(58460600/134107000)*100
# Out:
# 43.592504492681215

# %% [markdown]
# * 1년동안 134,107,000 사용
# * 매달 약 11,175,583.333333334 사용
# * 10회 이상 방문한 곳에서의 사용금액 58460600
# * 총 사용금액의 43.592504492681215%

# %% [markdown]
# ## 사용자 컬럼을 기준으로

# %% [markdown]
# ### 사용자

# %%
user = pd.pivot_table(data, index=['사용자'], aggfunc=np.sum)
user.head
# Out:
# <bound method NDFrame.head of              사용금액
# 사용자
# 관악구의회     1200000
# 도시건설위원장  17797320
# 보건복지위원장  17800000
# 부의장      23795550
# 의장       39389980
# 의회운영위원장  17799250
# 행정재경위원장  17774900>

# %%
# 횟수 컬럼 추가하기
user['횟수'] = data['사용자'].value_counts()
user
# Out:
#              사용금액   횟수
# 사용자
# 관악구의회     1200000    1
# 도시건설위원장  17797320  163
# 보건복지위원장  17800000  153
# 부의장      23795550  265
# 의장       39389980  254
# 의회운영위원장  17799250  135
# 행정재경위원장  17774900  180

# %%
# user 데이터 확인
user.sort_values(by='횟수', ascending=False)
# Out:
#              사용금액   횟수
# 사용자
# 부의장      23795550  265
# 의장       39389980  254
# 행정재경위원장  17774900  180
# 도시건설위원장  17797320  163
# 보건복지위원장  17800000  153
# 의회운영위원장  17799250  135
# 관악구의회     1200000    1

# %%
plt.figure(figsize=(10,8))
plt.bar(user.index, user['사용금액'])
plt.grid()
plt.ylabel('사용금액')
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.bar(user.index, user['횟수'])
plt.grid()
plt.show()

# %% [markdown]
# ### 의장's pick

# %%
# 의장's pick
user1 = data[data['사용자']=='의장']
user1.head()
# Out:
#      사용자       사용일시    사용금액  사용장소                주소  사용방법  \
# 1086  의장 2019-12-10  420000  감나무집  서울 관악구 관악로11길 20  신용카드
# 902   의장 2019-10-16  128000  감나무집  서울 관악구 관악로11길 20  신용카드
# 478   의장 2019-06-05  170000  감나무집  서울 관악구 관악로11길 20  신용카드
# 999   의장 2019-11-11  100000  감나무집  서울 관악구 관악로11길 20  신용카드
# 805   의장 2019-09-10   80000  감나무집  서울 관악구 관악로11길 20  신용카드
#
#                         사용내역      집행대상
# 1086   의정활동 및 의회운영 관련 업무유대경비  의장 외 20명
# 902   의정활동 및  의회운영 관련 업무유대경비   의장 외 3명
# 478    의정활동 및 의회운영 관련 업무유대경비   의장 등 8명
# 999    의정활동 및 의회운영 관련 업무유대경비   의장 외 4명
# 805    의정활동 및 의회운영 관련 업무유대경비    의장외 3명

# %%
# 피벗테이블 사용하기
user1_pt = pd.pivot_table(user1, index=['사용장소'], aggfunc=np.sum)
user1_pt
# Out:
#                사용금액
# 사용장소
# 감나무집        3137000
# 강강술래        2446000
# 강촌민물매운탕2호점   171000
# 개성보쌈          21000
# 갯벌낙지         210000
# ...             ...
# 파리바게뜨        105600
# 풍천장어         252000
# 하이보          942000
# 한류관          105000
# 해물나라         279000
#
# [66 rows x 1 columns]

# %%
# 금액순으로 정렬하기
user1_pt.sort_values(by='사용금액', ascending=False).head(10)
# Out:
#              사용금액
# 사용장소
# 우리동네고기집   7319900
# 제주은갈치     4435000
# 감나무집      3137000
# 신바람과일     2730000
# 강강술래      2446000
# 떡보의하루     2381600
# 시골집       1882000
# 남원추어탕     1610000
# 정가        1053000
# 생각보다맛있는집  1005000

# %% [markdown]
# ### 부의장's pick

# %%
user2 = data[data['사용자']=='부의장']
user2.head()
# Out:
#       사용자       사용일시    사용금액     사용장소                 주소  사용방법  \
# 605   부의장 2019-07-18   19200      KFC  서울 관악구 남부순환로 1735  신용카드
# 396   부의장 2019-05-04   71000  가야촌유황오리     서울 관악구 봉천로 407  신용카드
# 494   부의장 2019-06-06   10000      가츠몽     서울 관악구 관악로 169  신용카드
# 1115  부의장 2019-12-17  200000     감나무집   서울 관악구 관악로11길 20  신용카드
# 301   부의장 2019-04-07  108000     강강술래  서울 관악구 남부순환로 1660  신용카드
#
#                      사용내역      집행대상
# 605   의회운영 및 의정활동 관련 유대경비  부의장 등 3명
# 396   의회운영 및 의정활동 관련 유대경비  부의장 등 5명
# 494   의회운영 및 의정활동 관련 유대경비  부의장 등 2명
# 1115  의회운영 및 의정활동 관련 유대경비  부의장 등 8명
# 301   의회운영 및 의정활동 관련 유대경비  부의장 등 6명

# %%
# 피벗 사용하기
user2_pt = pd.pivot_table(user2, index=['사용장소'], aggfunc=np.sum)
user2_pt.head()
# Out:
#            사용금액
# 사용장소
# KFC       19200
# 가야촌유황오리   71000
# 가츠몽       10000
# 감나무집     200000
# 강강술래     108000

# %%
# 사용금액으로 정렬하기
user2_pt.sort_values(by='사용금액', ascending=False)
# Out:
#              사용금액
# 사용장소
# 은성숯불갈비    1867100
# 아리차이      1247000
# 숨은집       1007000
# 고창복의낙지세상   913000
# 당곡기사식당     846000
# ...           ...
# 본죽봉천점       18000
# 봉천동진순자김밥    17000
# 김밥천국        16500
# 가츠몽         10000
# 남원추어탕        9000
#
# [128 rows x 1 columns]

# %% [markdown]
# * 원그래프로 보여주면 재밌을듯(횟수, 금액 둘 다)

# %% [markdown]
# ## 사용일시 컬럼을 기준으로

# %% [markdown]
# ### 월 컬럼 추가하기

# %%
data.head()
# Out:
#          사용자       사용일시    사용금액       사용장소                   주소  사용방법  \
# 950  행정재경위원장 2019-10-03   15000       #207       서울 관악구 원신길 128  신용카드
# 757  행정재경위원장 2019-08-05   12200       #207       서울 관악구 원신길 128  신용카드
# 71   행정재경위원장 2019-01-03  100000   (주)소명생고기      서울 금천구 시흥대로 264  신용카드
# 72   행정재경위원장 2019-01-06   45500  (주)송원마포갈비  서울 영등포구 도림로147길 2-1  신용카드
# 883  도시건설위원장 2019-09-01    6500    406CAFE    서울 관악구 신림로29길 3-7  신용카드
#
#                       사용내역          집행대상
# 950  의정활동 및 상임위  관련 업무 간담회   행정재경위원장외 4명
# 757   의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명
# 71    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 6명
# 72    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명
# 883   의정활동 및 상임위 관련 업무 간담회   도시건설위원장외 2명

# %%
data['월'] = data['사용일시'].dt.month
data.head()
# Out:
#          사용자       사용일시    사용금액       사용장소                   주소  사용방법  \
# 950  행정재경위원장 2019-10-03   15000       #207       서울 관악구 원신길 128  신용카드
# 757  행정재경위원장 2019-08-05   12200       #207       서울 관악구 원신길 128  신용카드
# 71   행정재경위원장 2019-01-03  100000   (주)소명생고기      서울 금천구 시흥대로 264  신용카드
# 72   행정재경위원장 2019-01-06   45500  (주)송원마포갈비  서울 영등포구 도림로147길 2-1  신용카드
# 883  도시건설위원장 2019-09-01    6500    406CAFE    서울 관악구 신림로29길 3-7  신용카드
#
#                       사용내역          집행대상   월
# 950  의정활동 및 상임위  관련 업무 간담회   행정재경위원장외 4명  10
# 757   의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명   8
# 71    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 6명   1
# 72    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명   1
# 883   의정활동 및 상임위 관련 업무 간담회   도시건설위원장외 2명   9

# %% [markdown]
# ### 월별 금액 살펴보기

# %%
pd.pivot_table(data, index=['월'], aggfunc=np.sum)
# Out:
#         사용금액
# 월
# 1   14949400
# 2   10046300
# 3   10497200
# 4   11575580
# 5   11801000
# 6   10277700
# 7   11825190
# 8   10937200
# 9   10287500
# 10  10708500
# 11  11006780
# 12  11644650

# %% [markdown]
# * 월별로 지출한 금액은 비슷하다

# %% [markdown]
# ## 집행대상 칼럼을 기준으로 확인하기

# %%
data['집행대상'].unique()
# Out:
# array(['행정재경위원장외 4명', '행정재경위원장 등 4명', '행정재경위원장 등 6명', '도시건설위원장외 2명',
#        '부의장 등 3명', '의회운영위원장 등 7명', '행정재경위원장 등 5명', '보건복지위원장 등 2명',
#        '행정재경위원장  등 4명', '행정재경위원장외 3명', '보건복지위원장 등 3명', '부의장 등 5명',
#        '의회운영위원장 등 11명', '부의장 등 2명', '의회운영위원장 등 13명', '의장 외 20명',
#        '의장 외 3명', '의장 등 8명', '도시건설위원장 등 13명', '도시건설위원장 등 11명',
#        '보건복지위원장 등 11명', '의장 외 4명', '보건복지위원장 등 13명', '의장외 3명', '의장 등 7명',
#        '의장 등 3명', '의장 등 10명', '의장 등 16명', '의장 등 9명', '의장 외 12명',
#        '의장 등 2명', '의장 외 10명', '부의장 등 8명', '의장 등 11명', '의장 등 6명',
#        '보건복지위원장 등 10명', '의장 등 4명', '보건복지위원장외 1명', '도시건설위원장 등 6명',
#        '도시건설위원장 등 16명', '의장 외 13명', '의장 외 15명', '의장 외 7명', '의회운영위원장 등 4명',
#        '의장 등 12명', '부의장 등 6명', '의회운영위원장 등 6명', '의장 외 2명', '보건복지위원장 등 5명',
#        '보건복지위원장외 5명', '행정재경위원장 등 3명', '행정재경위원장 등 2명', '행정재경위원장외 2명',
#        '행정재경위원장 등 7명', '도시건설위원장외 6명', '의회운영위원장 등 12명', '도시건설위원장 등 5명',
#        '행정재경위원장 등 13명', '부의장 등 12명', '부의장 등 4명', '부의장 등 7명', '부의장 등 9명',
# ...

# %%
data['집행대상'].unique()[1][-3:-1]
# Out:
# ' 4'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1151 entries, 950 to 996
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용자     1151 non-null   object
#  1   사용일시    1151 non-null   datetime64[ns]
#  2   사용금액    1151 non-null   int64
#  3   사용장소    1145 non-null   object
#  4   주소      1145 non-null   object
#  5   사용방법    1151 non-null   object
#  6   사용내역    1151 non-null   object
#  7   집행대상    1151 non-null   object
#  8   월       1151 non-null   int64
# dtypes: datetime64[ns](1), int64(2), object(6)
# memory usage: 89.9+ KB

# %%
range(len(data))
# Out:
# range(0, 1151)

# %%
data['집행대상수'] = np.nan

# %%
for i in range(len(data['집행대상'])):
    data['집행대상수'].iloc[i] = data['집행대상'].iloc[i][-3:-1]
# Out:
# C:\Users\Playdata\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
data['집행대상'].iloc[0][-3:-1]
# Out:
# ' 4'

# %%
data['집행대상수'].iloc[0] = data['집행대상'].iloc[0][-3:-1]

# %%
data['집행대상수'].iloc[0]
# Out:
# ' 4'

# %%
data
# Out:
#          사용자       사용일시     사용금액       사용장소                   주소  사용방법  \
# 950  행정재경위원장 2019-10-03    15000       #207       서울 관악구 원신길 128  신용카드
# 757  행정재경위원장 2019-08-05    12200       #207       서울 관악구 원신길 128  신용카드
# 71   행정재경위원장 2019-01-03   100000   (주)소명생고기      서울 금천구 시흥대로 264  신용카드
# 72   행정재경위원장 2019-01-06    45500  (주)송원마포갈비  서울 영등포구 도림로147길 2-1  신용카드
# 883  도시건설위원장 2019-09-01     6500    406CAFE    서울 관악구 신림로29길 3-7  신용카드
# ..       ...        ...      ...        ...                  ...   ...
# 215       의장 2019-03-25    50000        NaN                  NaN    현금
# 370    관악구의회 2019-04-26  1200000        NaN                  NaN    현금
# 705       의장 2019-08-16    50000        NaN                  NaN    현금
# 907       의장 2019-10-18    50000        NaN                  NaN    현금
# 996       의장 2019-11-01    50000        NaN                  NaN    현금
#
#                       사용내역              집행대상   월 집행대상수
# 950  의정활동 및 상임위  관련 업무 간담회       행정재경위원장외 4명  10     4
# ...

# %%
data['집행대상수'].value_counts()
# Out:
#  5    162
#  4    156
#  3    119
#  6    115
#  8    105
#  7     98
#  2     62
#  9     60
# 10     48
# 11     42
# 12     36
# 13     28
# 16     23
# 15     17
# 14     15
# 20     14
#  1      6
# 21      6
# 34      6
# 인       5
# 35      3
# 22      3
# 18      3
#  의      2
# 19      2
# 17      2
# 25      2
# 29      2
# 26      2
# 41      1
# 호협      1
# 30      1
# 40      1
# 조사      1
# 주무      1
# 속의      1
# Name: 집행대상수, dtype: int64

# %%
data1 = data.copy()
data1.head()
# Out:
#          사용자       사용일시    사용금액       사용장소                   주소  사용방법  \
# 950  행정재경위원장 2019-10-03   15000       #207       서울 관악구 원신길 128  신용카드
# 757  행정재경위원장 2019-08-05   12200       #207       서울 관악구 원신길 128  신용카드
# 71   행정재경위원장 2019-01-03  100000   (주)소명생고기      서울 금천구 시흥대로 264  신용카드
# 72   행정재경위원장 2019-01-06   45500  (주)송원마포갈비  서울 영등포구 도림로147길 2-1  신용카드
# 883  도시건설위원장 2019-09-01    6500    406CAFE    서울 관악구 신림로29길 3-7  신용카드
#
#                       사용내역          집행대상   월 집행대상수
# 950  의정활동 및 상임위  관련 업무 간담회   행정재경위원장외 4명  10     4
# 757   의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명   8     4
# 71    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 6명   1     6
# 72    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명   1     4
# 883   의정활동 및 상임위 관련 업무 간담회   도시건설위원장외 2명   9     2

# %%
data1.loc[:, '집행대상수'].value_counts()
# Out:
#  5    162
#  4    156
#  3    119
#  6    115
#  8    105
#  7     98
#  2     62
#  9     60
# 10     48
# 11     42
# 12     36
# 13     28
# 16     23
# 15     17
# 14     15
# 20     14
#  1      6
# 21      6
# 34      6
# 인       5
# 35      3
# 22      3
# 18      3
#  의      2
# 19      2
# 17      2
# 25      2
# 29      2
# 26      2
# 41      1
# 호협      1
# 30      1
# 40      1
# 조사      1
# 주무      1
# 속의      1
# Name: 집행대상수, dtype: int64

# %%
data1 = data1['집행대상수']
data1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-210-e59ded9ed4cf> in <module>
# ----> 1 data1 = data1['집행대상수']
#       2 data1
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
data1[data1=='인 '] = np.nan

# %%
data1[data1==' 의'] = np.nan

# %%
data1[data1=='호협'] = np.nan

# %%
data1[data1=='조사'] = np.nan
data1[data1=='주무'] = np.nan
data1[data1=='속의'] = np.nan

# %%
data['집행대상수'] = data1
data['집행대상수'].unique()
# Out:
# array([' 4', ' 6', ' 2', ' 3', ' 7', ' 5', '11', '13', '20', ' 8', '10',
#        '16', ' 9', '12', ' 1', '15', '34', '21', '18', '19', '14', '35',
#        nan, '22', '30', '29', '17', '26', '41', '25', '40'], dtype=object)

# %%
data['집행대상수'] = data['집행대상수'].astype('float32')

# %%
data['집행대상수'].fillna(value=0, inplace=True)
data['집행대상수'].unique()
# Out:
# array([ 4.,  6.,  2.,  3.,  7.,  5., 11., 13., 20.,  8., 10., 16.,  9.,
#        12.,  1., 15., 34., 21., 18., 19., 14., 35.,  0., 22., 30., 29.,
#        17., 26., 41., 25., 40.], dtype=float32)

# %%
data['집행대상수'] = data['집행대상수'] + 1

# %%
data.head()
# Out:
#          사용자       사용일시    사용금액       사용장소                   주소  사용방법  \
# 950  행정재경위원장 2019-10-03   15000       #207       서울 관악구 원신길 128  신용카드
# 757  행정재경위원장 2019-08-05   12200       #207       서울 관악구 원신길 128  신용카드
# 71   행정재경위원장 2019-01-03  100000   (주)소명생고기      서울 금천구 시흥대로 264  신용카드
# 72   행정재경위원장 2019-01-06   45500  (주)송원마포갈비  서울 영등포구 도림로147길 2-1  신용카드
# 883  도시건설위원장 2019-09-01    6500    406CAFE    서울 관악구 신림로29길 3-7  신용카드
#
#                       사용내역          집행대상   월  집행대상수
# 950  의정활동 및 상임위  관련 업무 간담회   행정재경위원장외 4명  10    5.0
# 757   의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명   8    5.0
# 71    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 6명   1    7.0
# 72    의정활동 및 상임위 관련 업무 간담회  행정재경위원장 등 4명   1    5.0
# 883   의정활동 및 상임위 관련 업무 간담회   도시건설위원장외 2명   9    3.0

# %%
data[data['사용금액']==1400000]
# Out:
#    사용자       사용일시     사용금액   사용장소             주소  사용방법                   사용내역  \
# 22  의장 2019-01-28  1400000  신바람과일  서울 관악구 인헌길 14  신용카드  의회사무국 직원 설명절 격려 물품 지급
#
#           집행대상  월  집행대상수
# 22  사무국장 등 35명  1   36.0

# %%
pd.pivot_table(data, index=['사용장소'], aggfunc=np.sum).sort_values(by='사용금액', ascending=False)
# Out:
#             사용금액    월  집행대상수
# 사용장소
# 제주은갈치    8053000  395  571.0
# 우리동네고기집  7319900  142  233.0
# 옥천골      6801000  241  373.0
# 감나무집     6047500  155  284.0
# 통큰대박집    2985000   87  156.0
# ...          ...  ...    ...
# 오페라빈       11500    8    3.0
# 히포커피       10800    8    5.0
# 가츠몽        10000    6    3.0
# 카페드구띠에      7600    7    3.0
# 406CAFE     6500    9    3.0
#
# [432 rows x 3 columns]

# %%
8053000 / 571
# Out:
# 14103.327495621716

# %%
7319900 / 233
# Out:
# 31415.87982832618

# %%
pd.pivot_table(data, index=['사용장소'], aggfunc=np.sum).sort_values(by='집행대상수', ascending=False)
# Out:
#                사용금액    월  집행대상수
# 사용장소
# 제주은갈치       8053000  395  571.0
# 옥천골         6801000  241  373.0
# 감나무집        6047500  155  284.0
# 우리동네고기집     7319900  142  233.0
# 남원추어탕       1943000   93  193.0
# ...             ...  ...    ...
# 본죽봉천점         18000    2    3.0
# 본죽＆비빔밥        20000    1    3.0
# 카페드구띠에         7600    7    3.0
# 자연별곡서울대입구점    39800    3    3.0
# 홍콩반점          21000   12    2.0
#
# [432 rows x 3 columns]
