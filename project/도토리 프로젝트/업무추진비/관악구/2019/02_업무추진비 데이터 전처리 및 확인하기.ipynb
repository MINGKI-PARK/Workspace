# %%
# import os
# import random #데이터 샘플링
# from collections import Counter # count 용도

import numpy as np
import pandas as pd

# from geopy import distance # 거리 계산
# import geopy.distance
from tqdm import tqdm

# 결측치 확인
import missingno as msno

import warnings
warnings.filterwarnings('ignore')

# 시각화
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('fivethirtyeight')

# 한글, 마이너스 깨짐 방지
from matplotlib import rc, font_manager, rcParams
font=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family = font)
rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 데이터 확인하기

# %%
df = pd.read_csv('./dataset/2019 관악구 업무추진비.csv')
df.head()
# Out:
#    연번 사용자        사용일시   사용시간   사용금액   사용장소                    주소  사용방법  \
# 0   1  의장  2019-01-02  08:44  58500    완산정        서울 관악구 봉천로 484  신용카드
# 1   2  의장  2019-01-02  12:36  89000  제주은갈치        서울 관악구 관악로 139  신용카드
# 2   3  의장  2019-01-04  12:53  14000   아리차이         서울 관악구 신림동길 4  신용카드
# 3   4  의장  2019-01-09  12:33  77000  남원추어탕       서울 관악구 쑥고개로 135  신용카드
# 4   5  의장  2019-01-09  14:48  83300   카페베네  서울 관악구 남부순환로 2082-29  신용카드
#
#                     사용내역      집행대상
# 0  의정활동 및 의회운영 관련 업무휴대경비   의장 등 9명
# 1  의정활동 및 의회운영 관련 업무휴대경비   의장 등 7명
# 2  의정활동 및 의회운영 관련 업무휴대경비   의장 등 2명
# 3  의정활동 및 의회운영 관련 업무휴대경비   의장 등 7명
# 4  의정활동 및 의회운영 관련 업무휴대경비  의장 등 17명

# %%
df.tail()
# Out:
#        연번    사용자        사용일시   사용시간    사용금액   사용장소                   주소  사용방법  \
# 1999  101  의회사무국  2019-12-27  20:27  132000    시골집     서울 관악구 낙성대로 22-7  신용카드
# 2000  102  의회사무국  2019-12-30  13:00  220000   만리장성       서울 관악구 관악로 146  신용카드
# 2001  103  의회사무국  2019-12-30  13:08   87000    쌈마을  서울 관악구 남부순환로226길 31  신용카드
# 2002  104  의회사무국  2019-12-30  14:01  174000  장보고마트     서울 관악구 남부순환로230길  신용카드
# 2003  105  의회사무국  2019-12-30  20:24  123000  제주은갈치       서울 관악구 관악로 139  신용카드
#
#                      사용내역             집행대상
# 1999       의정업무 추진관계자 간담회       사무국장 등 10명
# 2000            사무국 직원 격려       의정팀장 등 10명
# 2001     의사팀 업무추진 관련 간담회비       의사팀 직원 10명
# 2002       부서운영 물품(음료) 구입  의원, 직원, 방문민원인 등
# 2003  신년인사회 추진 관련 관계자 간담회        의정팀장 등 7명

# %%
df.shape
# Out:
# (2004, 10)

# %%
df.columns
# Out:
# Index(['연번', '사용자', '사용일시', '사용시간', '사용금액', '사용장소', '주소', '사용방법', '사용내역',
#        '집행대상'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# 연번        0
# 사용자       0
# 사용일시      0
# 사용시간    452
# 사용금액      0
# 사용장소     11
# 주소       11
# 사용방법      0
# 사용내역      0
# 집행대상     28
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2004 entries, 0 to 2003
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      2004 non-null   int64
#  1   사용자     2004 non-null   object
#  2   사용일시    2004 non-null   object
#  3   사용시간    1552 non-null   object
#  4   사용금액    2004 non-null   int64
#  5   사용장소    1993 non-null   object
#  6   주소      1993 non-null   object
#  7   사용방법    2004 non-null   object
#  8   사용내역    2004 non-null   object
#  9   집행대상    1976 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 156.7+ KB

# %%
df.sum()
# Out:
# 연번                                                  88964
# 사용자     의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장의장...
# 사용일시    2019-01-022019-01-022019-01-042019-01-092019-0...
# 사용금액                                            224074380
# 사용방법    신용카드신용카드신용카드신용카드신용카드신용카드신용카드신용카드현금신용카드신용카드신용카드...
# 사용내역    의정활동 및 의회운영 관련 업무휴대경비의정활동 및 의회운영 관련 업무휴대경비의정활동...
# dtype: object

# %%
df['사용장소'].nunique()
# Out:
# 611

# %%
df['사용내역'].nunique()
# Out:
# 213

# %% [markdown]
# + 총 사용금액 224,074,380 (2억2천~)
# + 장소 611곳
#
# + 필요한 것
#     - 필요없는 컬럼 정리
#     - 컬럼 타입 변경
#     - 음식점인지 아닌지 구별하기
#     - 음식 카테고리 추가하기

# %% [markdown]
# ## 데이터 전처리하기
#
# + 필요없는 컬럼 삭제
# + 컬럼 데이터 타입 변경

# %%
# 사용방법 컬럼 확인
df['사용방법'].unique()
# Out:
# array(['신용카드', '현금', '제로페이'], dtype=object)

# %%
# 사용방법 컬럼 확인
df['사용자'].unique()
# Out:
# array(['의장', '부의장', '의회운영위원장', '행정재경위원장', '보건복지위원장', '도시건설위원장', '관악구의회',
#        '의회사무국'], dtype=object)

# %% [markdown]
# ### 사용일시 컬럼 날짜타입으로 변경

# %%
# 사용일시 컬럼 날짜타입으로 변경
df['사용일시'] = pd.to_datetime(df['사용일시'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2004 entries, 0 to 2003
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연번      2004 non-null   int64
#  1   사용자     2004 non-null   object
#  2   사용일시    2004 non-null   datetime64[ns]
#  3   사용시간    1552 non-null   object
#  4   사용금액    2004 non-null   int64
#  5   사용장소    1993 non-null   object
#  6   주소      1993 non-null   object
#  7   사용방법    2004 non-null   object
#  8   사용내역    2004 non-null   object
#  9   집행대상    1976 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 156.7+ KB

# %% [markdown]
# ### 결측치 확인 및 처리

# %%
# 먼저 결측값 얼마나 있는지 확인해보기
msno.bar(df, figsize=(7, 3))
plt.show()

# %%
df.isnull().sum()
# Out:
# 연번        0
# 사용자       0
# 사용일시      0
# 사용시간    452
# 사용금액      0
# 사용장소     11
# 주소       11
# 사용방법      0
# 사용내역      0
# 집행대상     28
# dtype: int64

# %%
# 사용시간 결측치 확인
df[df['사용시간'].isnull()]
# Out:
#       연번    사용자       사용일시 사용시간     사용금액  사용장소                주소  사용방법  \
# 8      9     의장 2019-01-11  NaN    50000   NaN               NaN    현금
# 215   22     의장 2019-03-25  NaN    50000   NaN               NaN    현금
# 370   87  관악구의회 2019-04-26  NaN  1200000   NaN               NaN    현금
# 705   16     의장 2019-08-16  NaN    50000   NaN               NaN    현금
# 907   13     의장 2019-10-18  NaN    50000   NaN               NaN    현금
# ...   ..    ...        ...  ...      ...   ...               ...   ...
# 1592  57  의회사무국 2019-07-31  NaN    89500  심가면옥   서울시 관악구 신림로 121  제로페이
# 1593  58  의회사무국 2019-07-31  NaN   290000   시골집  서울 관악구 낙성대로 22-7  제로페이
# 1627  34  의회사무국 2019-08-16  NaN    50000   NaN               NaN    현금
# 1782  45  의회사무국 2019-10-18  NaN    50000   NaN               NaN    현금
# 1809   3  의회사무국 2019-11-01  NaN    50000   NaN               NaN    현금
#
#                       사용내역              집행대상
# 8             의회운영 경조사비 지출           안OO 주무관
# 215   의장 의회운영업무추진비 경조사비 지출  김OO 주무관 빙부상 경조사금
# 370      강원도 산불 피해지원 성금 납부            재해구호협회
# 705      의장 의회운영업무추진비 경조사비          관악구의회 의원
# 907   의장 의회운영업무추진비 경조사비 지출         사무국 직원 1명
# ...                    ...               ...
# 1592        의정업무 추진관계자 간담회         사무국장 등 8명
# 1593            사무국 직원 격려         의정팀장 등 19명
# 1627        기관운영업무추진비 경조사비          관악구의회 의원
# 1782     기관운영업무추진비 경조사비 지출          의회사무국 직원
# 1809        기관운영업무추진비 경조사비             의원 1명
#
# [452 rows x 10 columns]

# %%
# 사용장소 결측치 확인
df[df['사용장소'].isnull()]
# Out:
#       연번    사용자       사용일시 사용시간     사용금액 사용장소   주소 사용방법                  사용내역  \
# 8      9     의장 2019-01-11  NaN    50000  NaN  NaN   현금          의회운영 경조사비 지출
# 215   22     의장 2019-03-25  NaN    50000  NaN  NaN   현금  의장 의회운영업무추진비 경조사비 지출
# 370   87  관악구의회 2019-04-26  NaN  1200000  NaN  NaN   현금     강원도 산불 피해지원 성금 납부
# 705   16     의장 2019-08-16  NaN    50000  NaN  NaN   현금     의장 의회운영업무추진비 경조사비
# 907   13     의장 2019-10-18  NaN    50000  NaN  NaN   현금  의장 의회운영업무추진비 경조사비 지출
# 996    2     의장 2019-11-01  NaN    50000  NaN  NaN   현금        의회운영업무추진비 경조사비
# 1176  26  의회사무국 2019-01-11  NaN    50000  NaN  NaN   현금          기관운영 경조사비 지출
# 1312  50  의회사무국 2019-03-25  NaN    50000  NaN  NaN   현금    기관운영 업무추진비 경조사비 지출
# 1627  34  의회사무국 2019-08-16  NaN    50000  NaN  NaN   현금        기관운영업무추진비 경조사비
# 1782  45  의회사무국 2019-10-18  NaN    50000  NaN  NaN   현금     기관운영업무추진비 경조사비 지출
# 1809   3  의회사무국 2019-11-01  NaN    50000  NaN  NaN   현금        기관운영업무추진비 경조사비
#
#                   집행대상
# 8              안OO 주무관
# 215   김OO 주무관 빙부상 경조사금
# 370             재해구호협회
# 705           관악구의회 의원
# 907          사무국 직원 1명
# 996              의원 1명
# 1176           안OO 주무관
# 1312  김OO 주무관 빙부상 경조사금
# 1627          관악구의회 의원
# 1782          의회사무국 직원
# 1809             의원 1명

# %%
# 집행대상 결측치 확인
df[df['집행대상'].isnull()]
# Out:
#       연번    사용자       사용일시   사용시간    사용금액        사용장소                   주소  \
# 1276  14  의회사무국 2019-03-07    NaN   17500         다이소    서울 관악구 남부순환로 1840
# 1335   8  의회사무국 2019-04-04    NaN  260000        진진식품       서울 관악구 난곡로 168
# 1368  41  의회사무국 2019-04-16    NaN  195900       장보고마트     서울 관악구 남부순환로230길
# 1369  42  의회사무국 2019-04-16    NaN    6000         다이소    서울 강남구 남부순환로 2748
# 1370  43  의회사무국 2019-04-16    NaN   39100       파리바게뜨           서울 관악구 봉천동
# 1371  44  의회사무국 2019-04-16    NaN   48000         김가네       서울 관악구 관악로 152
# 1392  65  의회사무국 2019-04-26    NaN  271500       장보고마트     서울 관악구 남부순환로230길
# 1393  66  의회사무국 2019-04-26    NaN    4000         다이소    서울 강남구 남부순환로 2748
# 1394  67  의회사무국 2019-04-26    NaN   84000        태창약국    서울 관악구 쑥고개로 126-1
# 1459  51  의회사무국 2019-05-22    NaN  172600  롯데리아（백령도점）       서울시 중구 세종대로 39
# 1480   3  의회사무국 2019-06-03    NaN  104100       장보고마트     서울 관악구 남부순환로230길
# 1481   4  의회사무국 2019-06-03    NaN   51200       쟝블랑제리       서울 관악구 낙성대역길 8
# 1523  46  의회사무국 2019-06-26    NaN  460590      (주)이마트        서울 서초구 매헌로 16
# 1524  47  의회사무국 2019-06-26    NaN   54000       쟝블랑제리       서울 관악구 낙성대역길 8
# 1525  48  의회사무국 2019-06-26    NaN   94000  베스트아울렛디시마트      서울 관악구 쑥고개로 103
# 1527  50  의회사무국 2019-06-27    NaN  119500        태창약국    서울 관악구 쑥고개로 126-1
# 1808   2  의회사무국 2019-11-01  17:18  147000         정관장    서울 관악구 남부순환로 1798
# 1873  67  의회사무국 2019-11-25  18:12  281850       장보고마트  서울 관악구 남부순환로230길 41
# 1877  71  의회사무국 2019-11-26  11:18  100000      송은희플라워       서울 관악구 낙성대로 34
# 1879  73  의회사무국 2019-11-26  16:10  300000        만리장성       서울 관악구 관악로 146
# 1880  74  의회사무국 2019-11-26  16:18   30000       장보고마트  서울 관악구 남부순환로230길 41
# 1884  78  의회사무국 2019-11-27  15:58  229740         피자헛       서울 관악구 관악로 165
# 1891  85  의회사무국 2019-11-28  15:27  333900       장보고마트  서울 관악구 남부순환로230길 41
# 1892  86  의회사무국 2019-11-28  15:37  140000          행초     서울 관악구 관악로 229-1
# 1893  87  의회사무국 2019-11-28  15:42   60000       만년닭강정       서울 관악구 관악로 211
# 1896  90  의회사무국 2019-11-29  14:50   72000    봉천동진순자김밥       서울 관악구 청룡1길 19
# 1897  91  의회사무국 2019-11-29  15:07   90000         김가네       서울 관악구 관악로 152
# 1956  58  의회사무국 2019-12-17  13:44   25000       크린에이드     서울 관악구 관악로11길 17
#
#       사용방법                             사용내역 집행대상
# 1276  신용카드                    부서운영 필요 물품 구입  NaN
# 1335  신용카드               의원 워크숍 사전준비 간식류 구입  NaN
# 1368  신용카드     창녕군협약식 추진관련 간담회 다과 및 행사용품 구입  NaN
# 1369  신용카드               창녕군협약식 행사관련 종이컵 구매  NaN
# 1370  신용카드            창녕군협약식 추진관련 간담회 다과 구입  NaN
# 1371  신용카드        창녕군협약식 참석 의원 및 수행직원 조식 구매  NaN
# 1392  신용카드           강릉기관방문 관련 다과 및 행사용품 구입  NaN
# 1393  신용카드               강릉기관방문 행사관련 종이컵 구매  NaN
# 1394  신용카드               강릉기관 방문 관련 비상약품 구매  NaN
# 1459  신용카드     의원워크숍 군부대 안보교육 관련 장병 위문간식 구매  NaN
# 1480  신용카드  2019년 관악구의회의원 청렴연수원 반부패교육 다과 구입  NaN
# 1481  신용카드  2019년 관악구의회의원 청렴연수원 반부패교육 다과 구입  NaN
# 1523  신용카드             의원 해외비교시찰 관련 준비물품 구입  NaN
# 1524  신용카드             의원 해외비교시찰 관련 준비물품 구입  NaN
# 1525  신용카드             의원 해외비교시찰 관련 준비물품 구입  NaN
# 1527  신용카드             의원 해외비교시찰 관련 비상약품 구입  NaN
# 1808  신용카드                  의원워크숍 기관방문 기념품비  NaN
# 1873  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1877  신용카드                   탈북모자 합동장례식 화환비  NaN
# 1879  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1880  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1884  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1891  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1892  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1893  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1896  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1897  신용카드                행정사무감사 관련 다과 등 구입  NaN
# 1956  신용카드                신년인사회 행사용 탁자보 세탁비  NaN

# %% [markdown]
# + 사용장소, 주소 결측치는 제거해도 된다.
# + 사용시간, 집행대상은 유의미한 데이터가 있어 컬럼만 삭제.

# %%
# 연번, 사용시간, 사용방법, 집행대상 컬럼 삭제
df = df.drop(['연번', '사용시간', '사용방법', '집행대상'], axis=1)
df.head()
# Out:
#   사용자       사용일시   사용금액   사용장소                    주소                   사용내역
# 0  의장 2019-01-02  58500    완산정        서울 관악구 봉천로 484  의정활동 및 의회운영 관련 업무휴대경비
# 1  의장 2019-01-02  89000  제주은갈치        서울 관악구 관악로 139  의정활동 및 의회운영 관련 업무휴대경비
# 2  의장 2019-01-04  14000   아리차이         서울 관악구 신림동길 4  의정활동 및 의회운영 관련 업무휴대경비
# 3  의장 2019-01-09  77000  남원추어탕       서울 관악구 쑥고개로 135  의정활동 및 의회운영 관련 업무휴대경비
# 4  의장 2019-01-09  83300   카페베네  서울 관악구 남부순환로 2082-29  의정활동 및 의회운영 관련 업무휴대경비

# %%
# 결측치 제거
df.dropna(inplace=True)

# %%
# 확인
df.isnull().sum()
# Out:
# 사용자     0
# 사용일시    0
# 사용금액    0
# 사용장소    0
# 주소      0
# 사용내역    0
# dtype: int64

# %%
df.shape
# Out:
# (1993, 6)

# %% [markdown]
# ### 사용장소 전처리

# %%
for i in df.index:
    if df.loc[i, '사용장소']=='GS슈퍼':
        df.loc[i, '사용장소'] = 'GS슈퍼마켓'
    elif df.loc[i, '사용장소']=='강강술래신림본동점':
        df.loc[i, '사용장소'] = '강강술래'
    elif df.loc[i, '사용장소']=='강촌민물매운탕２호점':
        df.loc[i, '사용장소'] = '강촌민물매운탕2호점'
    elif df.loc[i, '사용장소']=='고봉민김밥인':
        df.loc[i, '사용장소'] = '고봉민김밥'
    elif df.loc[i, '사용장소']=='김가네 관악구청점':
        df.loc[i, '사용장소'] = '김가네'

    
    
    elif df.loc[i, '사용장소']=='동강영양탕':
        df.loc[i, '사용장소'] = '동강염소탕'
    elif df.loc[i, '사용장소']=='맛고을칼국수＆찰보리':
        df.loc[i, '사용장소'] = '맛고을칼국수＆찰보리밥'
    elif df.loc[i, '사용장소']=='먹쉬돈나 서울대역점':
        df.loc[i, '사용장소'] = '먹쉬돈나'
    elif df.loc[i, '사용장소']=='명태어장(서울대점)':
        df.loc[i, '사용장소'] = '명태어장'
    elif df.loc[i, '사용장소']=='명품청기와감자탕미성점':
        df.loc[i, '사용장소'] = '명품청기와감자탕'
    elif df.loc[i, '사용장소']=='미가할매참품한우':
        df.loc[i, '사용장소'] = '미가할매집'
    elif df.loc[i, '사용장소']=='바우네나주곰탕　봉천':
        df.loc[i, '사용장소'] = '바우네나주곰탕'
        

        
        
    elif df.loc[i, '사용장소']=='봉이 구이대장':
        df.loc[i, '사용장소'] = '봉이구이대장'
    elif df.loc[i, '사용장소']=='사시사철흑염소.오리':
        df.loc[i, '사용장소'] = '사시사철흑염소오리'
        
        

    
    elif (df.loc[i, '사용장소']=='엔조파스타&피자') or (df.loc[i, '사용장소']=='ENZO(엔조)'):
        df.loc[i, '사용장소'] = '엔조 파스타&피자'
        
        
    elif (df.loc[i, '사용장소']=='영광수산장어1번가') or (df.loc[i, '사용장소']=='영광수산장어１번가'):
        df.loc[i, '사용장소'] = '영광수산숯불민물장어'
    
    
    elif (df.loc[i, '사용장소']=='이대감명품막창') or (df.loc[i, '사용장소']=='이대감왕족발'):
        df.loc[i, '사용장소'] = '이대감 명품막창'
    
    elif (df.loc[i, '사용장소']=='일커피　서울대입구점') or (df.loc[i, '사용장소']=='일커피 서울대입구점'):
        df.loc[i, '사용장소'] = '일커피'
                                            
    elif (df.loc[i, '사용장소']=='자연별곡 서울대입구점') or (df.loc[i, '사용장소']=='자연별곡서울대입구점'):
        df.loc[i, '사용장소'] = '자연별곡'
    
    elif (df.loc[i, '사용장소']=='작은따옴표 협동조합') or (df.loc[i, '사용장소']=='작은따옴표협동조합'):
        df.loc[i, '사용장소'] = '작은따옴표'
        
    elif (df.loc[i, '사용장소']=='커피빈') or (df.loc[i, '사용장소']=='커피빈코리아인'):
        df.loc[i, '사용장소'] = '커피빈코리아'
        
    elif (df.loc[i, '사용장소']=='콩심 서울대점') or (df.loc[i, '사용장소']=='콩심서울대점'):
        df.loc[i, '사용장소'] = '콩심'
        
        
    
    elif df.loc[i, '사용장소']=='종로계림닭도리탕':
        df.loc[i, '사용장소'] = '종로계림닭도리탕원조'
        
    elif df.loc[i, '사용장소']=='진부령　황태촌':
        df.loc[i, '사용장소'] = '진부령황태촌'    
    
    elif df.loc[i, '사용장소']=='진우리참치':
        df.loc[i, '사용장소'] = '진우리독도참치'    
        
    elif df.loc[i, '사용장소']=='카페모아관악구청점':
        df.loc[i, '사용장소'] = '카페모아'    
    
    elif df.loc[i, '사용장소']=='쿠팡㈜':
        df.loc[i, '사용장소'] = '쿠팡'       
    
    elif df.loc[i, '사용장소']=='태창약국':
        df.loc[i, '사용장소'] = '태창온누리약국'     
    
    elif df.loc[i, '사용장소']=='투썸플레이스':
        df.loc[i, '사용장소'] = '투썸서울대입구역'       
        
        
    elif (df.loc[i, '사용장소']=='난곡문성파리바게뜨') or (df.loc[i, '사용장소']=='난곡사거리 파리바게뜨'):
        df.loc[i, '사용장소'] = '파리바게뜨'
    
    elif (df.loc[i, '사용장소']=='서울대 파리바게뜨') or (df.loc[i, '사용장소']=='서울대입구역2호 파리바게뜨'):
        df.loc[i, '사용장소'] = '파리바게뜨'
    elif (df.loc[i, '사용장소']=='은천길입구 파리바게뜨') or (df.loc[i, '사용장소']=='파리바게뜨서울대입구'):
        df.loc[i, '사용장소'] = '파리바게뜨'
    elif (df.loc[i, '사용장소']=='파리바게트'):
        df.loc[i, '사용장소'] = '파리바게뜨'
    
    elif (df.loc[i, '사용장소']=='본죽 관악구청점') or (df.loc[i, '사용장소']=='본죽&본도시락'):
        df.loc[i, '사용장소'] = '본죽'
    elif (df.loc[i, '사용장소']=='본죽&비빔밥') or (df.loc[i, '사용장소']=='본죽봉천점'):
        df.loc[i, '사용장소'] = '본죽'   
    elif (df.loc[i, '사용장소']=='본죽＆비빔밥') or (df.loc[i, '사용장소']=='본죽＆비빔밥ｃａｆｅ'):
        df.loc[i, '사용장소'] = '본죽'
          
          
    elif (df.loc[i, '사용장소']=='서울대학교생협호암교수회관') or (df.loc[i, '사용장소']=='서울대학교생활협동조'):
        df.loc[i, '사용장소'] = '서울대학교'
          
          
    elif (df.loc[i, '사용장소']=='스타벅스 서울대입구역점'):
        df.loc[i, '사용장소'] = '스타벅스'
    
    elif (df.loc[i, '사용장소']=='아웃백') or (df.loc[i, '사용장소']=='아웃백스테이크'):
        df.loc[i, '사용장소'] = '아웃백스테이크하우스'
    
    elif (df.loc[i, '사용장소']=='삼백돈'):
        df.loc[i, '사용장소'] = '삼백돈돈가츠'      
    elif (df.loc[i, '사용장소']=='두부이야기봉천점'):
        df.loc[i, '사용장소'] = '두부이야기'
    elif (df.loc[i, '사용장소']=='얼큰수제비') or (df.loc[i, '사용장소']=='얼큰수제비 해물칼국수'):
        df.loc[i, '사용장소'] = '얼큰수제비해물칼국수'
        
    elif (df.loc[i, '사용장소']=='얼큰수제비') or (df.loc[i, '사용장소']=='얼큰수제비 해물칼국수'):
        df.loc[i, '사용장소'] = '얼큰수제비해물칼국수'
    elif (df.loc[i, '사용장소']=='풍년오리'):
        df.loc[i, '사용장소'] = '풍년옥'

# %%
df['사용장소'].value_counts()
# Out:
# 제주은갈치      93
# 시골집        45
# 옥천골        40
# 파리바게뜨      33
# 감나무집       33
#            ..
# 가야촌유황오리     1
# 리몽          1
# 대가한방오리      1
# 엉뚱한생고기      1
# 카페드구띠에      1
# Name: 사용장소, Length: 556, dtype: int64

# %% [markdown]
# + 사용장소를 557개로 좁힘.

# %% [markdown]
# ### 데이터 저장하기

# %%
# df.to_csv('./dataset/업무추진비_전체_20220317.csv', index=False)

# %% [markdown]
# ## 사용장소 컬럼별 데이터 확인하기

# %%
df1 = df.value_counts('사용장소').reset_index().sort_values('사용장소')
df1.reset_index(inplace=True)
df1.drop('index', axis=1, inplace=True)
df1
# Out:
#            사용장소  0
# 0          #207  2
# 1      (주)소명생고기  1
# 2     (주)송원마포갈비  1
# 3    (주)신세계페이먼츠  4
# 4     (주)신화아이푸드  1
# ..          ... ..
# 551        흥부보쌈  8
# 552        희로애락  2
# 553        희전명가  1
# 554        히포커피  1
# 555         Ｇ마켓  1
#
# [556 rows x 2 columns]

# %%
df2 = df.groupby('사용장소').sum()
df2.reset_index(inplace=True)
df2
# Out:
#            사용장소     사용금액
# 0          #207    27200
# 1      (주)소명생고기   100000
# 2     (주)송원마포갈비    45500
# 3    (주)신세계페이먼츠   546290
# 4     (주)신화아이푸드   469500
# ..          ...      ...
# 551        흥부보쌈  1167000
# 552        희로애락   508000
# 553        희전명가    88000
# 554        히포커피    10800
# 555         Ｇ마켓    76000
#
# [556 rows x 2 columns]

# %%
for i in range(len(df2)):
    if df2.loc[i, '사용장소']==df1.loc[i, '사용장소']:
        df2.loc[i, '방문횟수'] = df1.loc[i, 0]

# %%
df2.isnull().sum()
# Out:
# 사용장소    0
# 사용금액    0
# 방문횟수    0
# dtype: int64

# %%
# 방문횟수 int로 변경
df2['방문횟수'] = df2['방문횟수'].astype('int')
df2.head()
# Out:
#          사용장소    사용금액  방문횟수
# 0        #207   27200     2
# 1    (주)소명생고기  100000     1
# 2   (주)송원마포갈비   45500     1
# 3  (주)신세계페이먼츠  546290     4
# 4   (주)신화아이푸드  469500     1

# %%
df2.sort_values('방문횟수', ascending=False).head(30)
# Out:
#            사용장소      사용금액  방문횟수
# 431       제주은갈치  11714000    93
# 285         시골집   9381000    45
# 346         옥천골   6801000    40
# 79        남원추어탕   3146000    33
# 506       파리바게뜨   1125300    33
# 23         감나무집   6527500    33
# 239         산야로   1916000    31
# 338        오리오리   2076000    31
# 298         쌈마을   4350000    26
# 334       옛날육개장   2664000    26
# 402       장보고마트   6522210    25
# 520         하이보   4470000    23
# 122       떡보의하루   3453600    22
# 481          콩심    540000    22
# 359     우리동네고기집   7319900    22
# 146        만리장성   2247000    21
# 25         강강술래   5068500    21
# 249    생각보다맛있는집   1158000    21
# 382      은성숯불갈비   1867100    19
# 453         청능장   1009000    19
# 321  얼큰수제비해물칼국수    614500    18
# 314       어메칼국수    768500    18
# 483          쿠팡   4820410    18
# 528        해물나라   1892000    17
# 217          본죽    615000    15
# 469        카페모아    452900    14
# 162     명품횡성한우가   3230000    13
# 501       통큰대박집   2985000    13
# 411       쟝블랑제리    644550    13
# 54           금비   2756000    12

# %%
df2 = df2[['사용장소', '방문횟수', '사용금액']]
df2
# Out:
#            사용장소  방문횟수     사용금액
# 0          #207     2    27200
# 1      (주)소명생고기     1   100000
# 2     (주)송원마포갈비     1    45500
# 3    (주)신세계페이먼츠     4   546290
# 4     (주)신화아이푸드     1   469500
# ..          ...   ...      ...
# 551        흥부보쌈     8  1167000
# 552        희로애락     2   508000
# 553        희전명가     1    88000
# 554        히포커피     1    10800
# 555         Ｇ마켓     1    76000
#
# [556 rows x 3 columns]

# %% [markdown]
# ### 데이터 저장하기

# %%
# df2.to_csv('./dataset/업무추진비_사용장소별_556.csv', index=False)

# %% [markdown]
# + 잘못 기재된 데이터들을 확인하는 작업이 필요하다.

# %%
len(df2[df2['방문횟수']>3])
# Out:
# 127

# %% [markdown]
# ## 사용자 컬럼별 데이터 확인하기

# %%
df['사용자'].unique()
# Out:
# array(['의장', '부의장', '의회운영위원장', '행정재경위원장', '보건복지위원장', '도시건설위원장', '의회사무국'],
#       dtype=object)

# %%
df_user_1 = df[df['사용자']=='의장']['사용장소'].value_counts().reset_index()
df_user_1 = df_user_1.sort_values('index').reset_index().drop('level_0', axis=1)
df_user_1
# Out:
#          index  사용장소
# 0         감나무집    18
# 1         강강술래     7
# 2   강촌민물매운탕2호점     1
# 3         개성보쌈     1
# 4         갯벌낙지     1
# ..         ...   ...
# 60       파리바게뜨     3
# 61        풍천장어     1
# 62         하이보     4
# 63         한류관     1
# 64        해물나라     2
#
# [65 rows x 2 columns]

# %%
df_user_2 = df[df['사용자']=='의장'].groupby('사용장소').sum().reset_index()

for i in df_user_1.index:
    if df_user_2.loc[i, '사용장소'] == df_user_1.loc[i, 'index']:
        df_user_2.loc[i, '방문횟수'] = df_user_1.loc[i, '사용장소']

df_user_2['방문횟수'] = df_user_2['방문횟수'].astype('int')
df_user_2 = df_user_2[['사용장소', '방문횟수', '사용금액']]

df_user_2.sort_values('방문횟수', ascending=False).head()
# Out:
#         사용장소  방문횟수     사용금액
# 50     제주은갈치    33  4435000
# 44   우리동네고기집    22  7319900
# 0       감나무집    18  3137000
# 24  생각보다맛있는집    16  1005000
# 8      남원추어탕    15  1610000

# %% [markdown]
# ### 함수 만들어보기

# %%
def df_user(user):
    df_user_1 = df[df['사용자']==user]['사용장소'].value_counts().reset_index()
    df_user_1 = df_user_1.sort_values('index').reset_index().drop('level_0', axis=1)
    
    df_user_2 = df[df['사용자']==user].groupby('사용장소').sum().reset_index()

    for i in df_user_1.index:
        if df_user_2.loc[i, '사용장소'] == df_user_1.loc[i, 'index']:
            df_user_2.loc[i, '방문횟수'] = df_user_1.loc[i, '사용장소']

    df_user_2['방문횟수'] = df_user_2['방문횟수'].astype('int')
    df_user_2 = df_user_2[['사용장소', '방문횟수', '사용금액']]

    return df_user_2.sort_values('방문횟수', ascending=False).head()

# %%
df_user('의장')
# Out:
#         사용장소  방문횟수     사용금액
# 50     제주은갈치    33  4435000
# 44   우리동네고기집    22  7319900
# 0       감나무집    18  3137000
# 24  생각보다맛있는집    16  1005000
# 8      남원추어탕    15  1610000

# %%
df_user('부의장')
# Out:
#         사용장소  방문횟수     사용금액
# 80    은성숯불갈비    19  1867100
# 20    당곡기사식당    11   846000
# 6   고창복의낙지세상    10   913000
# 7     구수옥설렁탕     9   586000
# 66      아리차이     7  1247000

# %%
df_user('의회운영위원장')
# Out:
#        사용장소  방문횟수     사용금액
# 17      다리목    11  2560000
# 38     북경반점     7   763000
# 61    장터순대국     5   743000
# 26  명품횡성한우가     5   602000
# 9        김밥     5  1021000

# %%
df_user('행정재경위원장')
# Out:
#       사용장소  방문횟수     사용금액
# 87   통큰대박집    10  2435000
# 74    전진식당    10   314000
# 8   거목쟁반짜장     8   136500
# 85      콩심     8   136000
# 15      금비     6  1749000

# %%
df_user('보건복지위원장')
# Out:
#        사용장소  방문횟수     사용금액
# 34      옥천골    37  6065000
# 49    제주은갈치    20  3097000
# 2      감나무집     6  1026000
# 47    정육점식당     5   227000
# 20  목포부부아구찜     5   580000

# %%
df_user('도시건설위원장')
# Out:
#       사용장소  방문횟수     사용금액
# 98   파리바게뜨     8   281400
# 109   흥부보쌈     5   666000
# 45     사랑방     5   951000
# 25    만리장성     5   384500
# 1     감나무집     5  1684500

# %%
df_user('의회사무국')
# Out:
#       사용장소  방문횟수     사용금액
# 112    시골집    33  6855000
# 88     산야로    29  1867000
# 173  제주은갈치    29  3661000
# 133   오리오리    29  1949000
# 162  장보고마트    25  6522210

# %% [markdown]
# ## 사용일시 컬럼으로 데이터 확인하기
#
# + 시계열 그래프 그려보기
# + 월별 사용 금액 확인하기 -> 년월 컬럼 추가
# + 계절별 사용 금액 확인하기 -> 계절 컬럼 추가

# %%
df
# Out:
#         사용자       사용일시    사용금액   사용장소                    주소  \
# 0        의장 2019-01-02   58500    완산정        서울 관악구 봉천로 484
# 1        의장 2019-01-02   89000  제주은갈치        서울 관악구 관악로 139
# 2        의장 2019-01-04   14000   아리차이         서울 관악구 신림동길 4
# 3        의장 2019-01-09   77000  남원추어탕       서울 관악구 쑥고개로 135
# 4        의장 2019-01-09   83300   카페베네  서울 관악구 남부순환로 2082-29
# ...     ...        ...     ...    ...                   ...
# 1999  의회사무국 2019-12-27  132000    시골집      서울 관악구 낙성대로 22-7
# 2000  의회사무국 2019-12-30  220000   만리장성        서울 관악구 관악로 146
# 2001  의회사무국 2019-12-30   87000    쌈마을   서울 관악구 남부순환로226길 31
# 2002  의회사무국 2019-12-30  174000  장보고마트      서울 관악구 남부순환로230길
# 2003  의회사무국 2019-12-30  123000  제주은갈치        서울 관악구 관악로 139
#
#                        사용내역
# 0     의정활동 및 의회운영 관련 업무휴대경비
# 1     의정활동 및 의회운영 관련 업무휴대경비
# 2     의정활동 및 의회운영 관련 업무휴대경비
# 3     의정활동 및 의회운영 관련 업무휴대경비
# 4     의정활동 및 의회운영 관련 업무휴대경비
# ...                     ...
# 1999         의정업무 추진관계자 간담회
# 2000              사무국 직원 격려
# 2001       의사팀 업무추진 관련 간담회비
# 2002         부서운영 물품(음료) 구입
# 2003    신년인사회 추진 관련 관계자 간담회
#
# [1993 rows x 6 columns]

# %% [markdown]
# ### 시계열 그래프 그려보기

# %%
# 년월일 시계열 그래프
plt.figure(figsize=(20, 10))
sns.lineplot(x='사용일시', y='사용금액', data=df)
plt.show()

# %%
df.groupby('사용일시').sum().reset_index()

plt.figure(figsize=(20, 10))
sns.lineplot(x='사용일시', y='사용금액', data=df.groupby('사용일시').sum().reset_index())
plt.show()

# %% [markdown]
# ### 년월 컬럼 추가하기

# %%
df['사용년월'] = df['사용일시'].dt.strftime('%Y-%m')
df.head()
# Out:
#   사용자       사용일시   사용금액   사용장소                    주소                   사용내역  \
# 0  의장 2019-01-02  58500    완산정        서울 관악구 봉천로 484  의정활동 및 의회운영 관련 업무휴대경비
# 1  의장 2019-01-02  89000  제주은갈치        서울 관악구 관악로 139  의정활동 및 의회운영 관련 업무휴대경비
# 2  의장 2019-01-04  14000   아리차이         서울 관악구 신림동길 4  의정활동 및 의회운영 관련 업무휴대경비
# 3  의장 2019-01-09  77000  남원추어탕       서울 관악구 쑥고개로 135  의정활동 및 의회운영 관련 업무휴대경비
# 4  의장 2019-01-09  83300   카페베네  서울 관악구 남부순환로 2082-29  의정활동 및 의회운영 관련 업무휴대경비
#
#       사용년월
# 0  2019-01
# 1  2019-01
# 2  2019-01
# 3  2019-01
# 4  2019-01

# %%
df.groupby('사용년월').sum()
# Out:
#              사용금액
# 사용년월
# 2019-01  20284810
# 2019-02  14056730
# 2019-03  15029600
# 2019-04  20979920
# 2019-05  20850600
# 2019-06  15708240
# 2019-07  16732640
# 2019-08  15648850
# 2019-09  16351510
# 2019-10  19882210
# 2019-11  20882330
# 2019-12  25966940

# %%
# 바 그래프
plt.figure(figsize=(10, 10))
sns.barplot(x='사용년월', y='사용금액', data=df.groupby('사용년월').sum().reset_index())
plt.xticks(rotation=45)
plt.show()

# %%
# 바 그래프
plt.figure(figsize=(10, 10))
sns.barplot(x='사용년월', y='사용금액', data=df[df['사용자']=='의장'], color='red')
sns.barplot(x='사용년월', y='사용금액', data=df[df['사용자']=='부의장'], color='blue')

plt.xticks(rotation=45)
plt.show()

# %%
df_group_month = df.groupby(['사용년월', '사용자']).sum().reset_index()
df_group_month
# Out:
#        사용년월      사용자      사용금액
# 0   2019-01  도시건설위원장   2498250
# 1   2019-01  보건복지위원장   1464500
# 2   2019-01      부의장   2670150
# 3   2019-01       의장   4431500
# 4   2019-01    의회사무국   5385410
# ..      ...      ...       ...
# 78  2019-12      부의장    974000
# 79  2019-12       의장   5718950
# 80  2019-12    의회사무국  14322290
# 81  2019-12  의회운영위원장   1230000
# 82  2019-12  행정재경위원장   3188400
#
# [83 rows x 3 columns]

# %%
# 바 그래프
plt.figure(figsize=(10, 10))
sns.barplot(x='사용년월', y='사용금액', data=df_group_month[df_group_month['사용자']=='의장'], color='red')
sns.barplot(x='사용년월', y='사용금액', data=df_group_month[df_group_month['사용자']=='부의장'], color='blue')

plt.xticks(rotation=45)
plt.show()

# %%
df_group_month[df_group_month['사용년월']=='2019-02']
# Out:
#        사용년월      사용자     사용금액
# 7   2019-02  도시건설위원장  1830400
# 8   2019-02  보건복지위원장  1701500
# 9   2019-02      부의장  2555200
# 10  2019-02       의장  2415200
# 11  2019-02    의회사무국  4010430
# 12  2019-02  의회운영위원장   554000
# 13  2019-02  행정재경위원장   990000

# %%
# 시계열 그래프
df.groupby('사용년월').sum()

plt.figure(figsize=(20, 10))
sns.lineplot(x='사용년월', y='사용금액', data=df.groupby('사용년월').sum().reset_index())
plt.show()

# %% [markdown]
# ### 계절 컬럼 추가하기
#
# + 계절별 맛집 파악하기

# %%
df['계절'] = np.nan

for i in df.index:
    # 봄
    if (df.loc[i, '사용년월']=='2019-03') or (df.loc[i, '사용년월']=='2019-04') or (df.loc[i, '사용년월']=='2019-05'):
        df.loc[i, '계절'] = '봄'
    
    # 여름
    elif (df.loc[i, '사용년월']=='2019-06') or (df.loc[i, '사용년월']=='2019-07') or (df.loc[i, '사용년월']=='2019-08'):
        df.loc[i, '계절'] = '여름'
        
    # 가을
    elif (df.loc[i, '사용년월']=='2019-09') or (df.loc[i, '사용년월']=='2019-10') or (df.loc[i, '사용년월']=='2019-11'):
        df.loc[i, '계절'] = '가을'
    
    # 겨울
    elif (df.loc[i, '사용년월']=='2019-12') or (df.loc[i, '사용년월']=='2019-01') or (df.loc[i, '사용년월']=='2019-02'):
        df.loc[i, '계절'] = '겨울'

# %%
df[df['계절']=='봄']
# Out:
#         사용자       사용일시    사용금액      사용장소                   주소  \
# 194      의장 2019-03-05  144000  구름산원주추어탕      서울 관악구 관천로 47-1
# 195      의장 2019-03-05  270000   우리동네고기집       서울 관악구 인헌6길 24
# 196      의장 2019-03-06   39000  생각보다맛있는집       서울 관악구 관악로 152
# 197      의장 2019-03-06   15000      베리베리       서울 관악구 관악로 148
# 198      의장 2019-03-07   72000     제주은갈치       서울 관악구 관악로 139
# ...     ...        ...     ...       ...                  ...
# 1473  의회사무국 2019-05-31  225240   신세계페이먼츠     서울 중구 남대문시장10길 2
# 1474  의회사무국 2019-05-31  345000     장보고마트     서울 관악구 남부순환로230길
# 1475  의회사무국 2019-05-31   38000     파리바게뜨        서울 관악구 은천로 86
# 1476  의회사무국 2019-05-31  190000       시골집     서울 관악구 낙성대로 22-8
# 1477  의회사무국 2019-05-31   60000       삼미옥  서울 관악구 남부순환로 1829-6
#
#                             사용내역     사용년월 계절
# 194        의정활동 및 의회운영 관련 업무유대경비  2019-03  봄
# 195        의정활동 및 의회운영 관련 업무유대경비  2019-03  봄
# 196        의정활동 및 의회운영 관련 업무유대경비  2019-03  봄
# 197        의정활동 및 의회운영 관련 업무유대경비  2019-03  봄
# 198        의정활동 및 의회운영 관련 업무유대경비  2019-03  봄
# ...                          ...      ... ..
# 1473           의원연구실 소요물품(다과) 구입  2019-05  봄
# 1474           의원연구실 소요물품(다과) 구입  2019-05  봄
# 1475  의회업무 추진을 위한 직원 및 관계자 간담회 등  2019-05  봄
# 1476                   사무국 직원 격려  2019-05  봄
# 1477            의안 자료연구 및 검토 간담회  2019-05  봄
#
# [495 rows x 8 columns]

# %%
# 봄
df[df['계절']=='봄']['사용장소'].value_counts().reset_index().head(10)
# Out:
#    index  사용장소
# 0  제주은갈치    22
# 1    옥천골    13
# 2    시골집    12
# 3   오리오리    12
# 4   감나무집    10
# 5   명태어장     8
# 6  파리바게뜨     8
# 7   강강술래     7
# 8    청능장     7
# 9     콩심     7

# %% [markdown]
# + 다른 계절도 확인해보자

# %%
# 여름
df[df['계절']=='여름']['사용장소'].value_counts().reset_index().head(10)
# Out:
#    index  사용장소
# 0  제주은갈치    20
# 1  옛날육개장    13
# 2    옥천골    11
# 3  파리바게뜨     9
# 4    쌈마을     8
# 5    시골집     8
# 6    하이보     8
# 7     콩심     7
# 8   오리오리     7
# 9   해물나라     7

# %%
# 가을
df[df['계절']=='가을']['사용장소'].value_counts().reset_index().head(10)
# Out:
#     index  사용장소
# 0   제주은갈치    21
# 1     시골집    15
# 2     산야로    14
# 3     하이보    11
# 4     옥천골    11
# 5  은성숯불갈비     9
# 6   옛날육개장     9
# 7   남원추어탕     9
# 8    페리카나     9
# 9   떡보의하루     7

# %%
# 겨울
df[df['계절']=='겨울']['사용장소'].value_counts().reset_index().head(10)
# Out:
#       index  사용장소
# 0     제주은갈치    30
# 1      감나무집    14
# 2     남원추어탕    13
# 3       시골집    10
# 4   우리동네고기집     9
# 5     파리바게뜨     9
# 6       쌈마을     8
# 7       산야로     7
# 8  생각보다맛있는집     7
# 9     쟝블랑제리     6

# %%
df.groupby('계절').sum()
# Out:
#         사용금액
# 계절
# 가을  57116050
# 겨울  60308480
# 봄   56860120
# 여름  48089730

# %%
# 바 그래프
plt.figure(figsize=(10, 10))
sns.barplot(x='계절', y='사용금액', data=df.groupby('계절').sum().reset_index())
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 카테고리 컬럼별 데이터 확인하기
#
# + 3번이상 방문한 곳을 기준으로 카테고리 추가

# %%
df2.shape
# Out:
# (556, 3)

# %%
df2[df2['방문횟수']>7].shape
# Out:
# (59, 3)

# %%
# 방문횟수 8이상
(59 / 557) * 100 # 상위 10%
# Out:
# 10.59245960502693

# %%
df2[df2['방문횟수']>3].shape
# Out:
# (127, 3)

# %%
# 방문횟수 4이상
(127 / 557) * 100 # 상위 20%
# Out:
# 22.800718132854577

# %%
df3 = df2[df2['방문횟수']>3]
df3.index = range(len(df3))
df3
# Out:
#            사용장소  방문횟수     사용금액
# 0    (주)신세계페이먼츠     4   546290
# 1          11번가     4   232240
# 2        GS슈퍼마켓     4   381680
# 3           가마솥     4   224000
# 4          감나무집    33  6527500
# ..          ...   ...      ...
# 122        해물나라    17  1892000
# 123        홍콩반점     7   278500
# 124          황복     6   390000
# 125         후포리     4   535000
# 126        흥부보쌈     8  1167000
#
# [127 rows x 3 columns]

# %% [markdown]
# ### 데이터 저장하기

# %%
# df3.to_csv('./dataset/업무추진비_사용장소별_over3.csv', index=False)

# %%
df_cate = pd.read_csv('./dataset/업무추진비_사용장소별_카테고리_최종.csv')
df_cate
# Out:
#            사용장소  방문횟수     사용금액 카테고리
# 0    (주)신세계페이먼츠     4   546290    -
# 1          11번가     4   232240    -
# 2        GS슈퍼마켓     4   381680    -
# 3           가마솥     4   224000  보양식
# 4          감나무집    33  6527500   한식
# ..          ...   ...      ...  ...
# 122        해물나라    17  1892000   해물
# 123        홍콩반점     7   278500   중식
# 124          황복     6   390000  보양식
# 125         후포리     4   535000   해물
# 126        흥부보쌈     8  1167000   고기
#
# [127 rows x 4 columns]

# %%
df_cate = df_cate[df_cate['카테고리']!='-']
df_cate.index = range(len(df_cate))
df_cate
# Out:
#            사용장소  방문횟수     사용금액 카테고리
# 0           가마솥     4   224000  보양식
# 1          감나무집    33  6527500   한식
# 2          강강술래    21  5068500   고기
# 3    강촌민물매운탕2호점     7   547000   해물
# 4           갯바위     6   458000   해물
# ..          ...   ...      ...  ...
# 114        해물나라    17  1892000   해물
# 115        홍콩반점     7   278500   중식
# 116          황복     6   390000  보양식
# 117         후포리     4   535000   해물
# 118        흥부보쌈     8  1167000   고기
#
# [119 rows x 4 columns]

# %% [markdown]
# ### 카테고리 수정
#
# + 해물 → 해물, 생선요리
#     - 해물이라는 카테고리가 음식점 전부를 대표하기 부족한 부분이 있어 생선요리를 포함한 카테고리로 수정

# %%
# df_cate[df_cate['카테고리']=='해물']['카테고리'].apply(lambda x: x + ', 생선요리')

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='카테고리', data=df_cate)
plt.xticks(rotation=90)
plt.show()

# %%
df_cate.groupby('카테고리').count()
# Out:
#         사용장소  방문횟수  사용금액
# 카테고리
# 고기        18    18    18
# 국밥류       11    11    11
# 기타         5     5     5
# 면류         5     5     5
# 보양식       12    12    12
# 분식         5     5     5
# 일식         6     6     6
# 주점         2     2     2
# 중식        10    10    10
# 카페&디저트    14    14    14
# 한식        16    16    16
# 해물        15    15    15

# %%
df_cate[df_cate['카테고리']=='주점']
# Out:
#      사용장소  방문횟수    사용금액 카테고리
# 82  작은따옴표     4  930000   주점
# 83    장군집     7  263000   주점

# %% [markdown]
# ## 위치 데이터 추가

# %%
df_loc = pd.read_csv('./dataset/관악구 업무추진비 위치.csv')
df_loc
# Out:
#            사용장소                               주소     사용금액        lat  \
# 0          #207              서울 관악구 원신길 128 #207    27200  37.506248
# 1      (주)소명생고기         서울 금천구 시흥대로 264 (주)소명생고기   100000  37.457203
# 2     (주)송원마포갈비    서울 영등포구 도림로147길 2-1 (주)송원마포갈비    45500  37.516644
# 3    (주)신세계페이먼츠      서울 중구 남대문시장10길 2 (주)신세계페이먼츠   546290  37.560333
# 4     (주)신화아이푸드  충청북도 청주시 서원구 1순환로 886 (주)신화아이푸드   469500  36.616615
# ..          ...                              ...      ...        ...
# 586        흥부보쌈         서울 관악구 신림로59길 15-13 흥부보쌈  1167000  37.482655
# 587        희로애락              서울 관악구 봉천로 465 희로애락   508000  37.482469
# 588        희전명가          서울 관악구 남부순환로180길 6 희전명가    88000  37.485211
# 589        히포커피            서울 관악구 신림로23길 21 히포커피    10800  37.469969
# 590         Ｇ마켓                   서울 강남구 역삼동 Ｇ마켓    76000  37.499971
#
#             lng             거리
# 0    126.913952    4559.495385
# 1    126.899928    5111.949204
# 2    126.889236    6969.211685
# 3    126.982963    9555.694239
# 4    127.469836  106263.797527
# ..          ...            ...
# 586  126.929366    2019.981634
# 587  126.951614     486.587335
# 588  126.931504    1935.672971
# 589  126.934968    1717.771051
# 590  127.036481    7880.609105
#
# [591 rows x 6 columns]

# %%
for i in df_loc.index:
    if df_loc.loc[i, '사용장소']=='GS슈퍼':
        df_loc.loc[i, '사용장소'] = 'GS슈퍼마켓'
    elif df_loc.loc[i, '사용장소']=='강강술래신림본동점':
        df_loc.loc[i, '사용장소'] = '강강술래'
    elif df_loc.loc[i, '사용장소']=='강촌민물매운탕２호점':
        df_loc.loc[i, '사용장소'] = '강촌민물매운탕2호점'
    elif df_loc.loc[i, '사용장소']=='고봉민김밥인':
        df_loc.loc[i, '사용장소'] = '고봉민김밥'
    elif df_loc.loc[i, '사용장소']=='김가네 관악구청점':
        df_loc.loc[i, '사용장소'] = '김가네'

    
    
    elif df_loc.loc[i, '사용장소']=='동강영양탕':
        df_loc.loc[i, '사용장소'] = '동강염소탕'
    elif df_loc.loc[i, '사용장소']=='맛고을칼국수＆찰보리':
        df_loc.loc[i, '사용장소'] = '맛고을칼국수＆찰보리밥'
    elif df_loc.loc[i, '사용장소']=='먹쉬돈나 서울대역점':
        df_loc.loc[i, '사용장소'] = '먹쉬돈나'
    elif df_loc.loc[i, '사용장소']=='명태어장(서울대점)':
        df_loc.loc[i, '사용장소'] = '명태어장'
    elif df_loc.loc[i, '사용장소']=='명품청기와감자탕미성점':
        df_loc.loc[i, '사용장소'] = '명품청기와감자탕'
    elif df_loc.loc[i, '사용장소']=='미가할매참품한우':
        df_loc.loc[i, '사용장소'] = '미가할매집'
    elif df_loc.loc[i, '사용장소']=='바우네나주곰탕　봉천':
        df_loc.loc[i, '사용장소'] = '바우네나주곰탕'
        

        
        
    elif df_loc.loc[i, '사용장소']=='봉이 구이대장':
        df_loc.loc[i, '사용장소'] = '봉이구이대장'
    elif df_loc.loc[i, '사용장소']=='사시사철흑염소.오리':
        df_loc.loc[i, '사용장소'] = '사시사철흑염소오리'
        
        

    
    elif (df_loc.loc[i, '사용장소']=='엔조파스타&피자') or (df_loc.loc[i, '사용장소']=='ENZO(엔조)'):
        df_loc.loc[i, '사용장소'] = '엔조 파스타&피자'
        
        
    elif (df_loc.loc[i, '사용장소']=='영광수산장어1번가') or (df_loc.loc[i, '사용장소']=='영광수산장어１번가'):
        df_loc.loc[i, '사용장소'] = '영광수산숯불민물장어'
    
    
    elif (df_loc.loc[i, '사용장소']=='이대감명품막창') or (df_loc.loc[i, '사용장소']=='이대감왕족발'):
        df_loc.loc[i, '사용장소'] = '이대감 명품막창'
    
    elif (df_loc.loc[i, '사용장소']=='일커피　서울대입구점') or (df_loc.loc[i, '사용장소']=='일커피 서울대입구점'):
        df_loc.loc[i, '사용장소'] = '일커피'
                                            
    elif (df_loc.loc[i, '사용장소']=='자연별곡 서울대입구점') or (df_loc.loc[i, '사용장소']=='자연별곡서울대입구점'):
        df_loc.loc[i, '사용장소'] = '자연별곡'
    
    elif (df_loc.loc[i, '사용장소']=='작은따옴표 협동조합') or (df_loc.loc[i, '사용장소']=='작은따옴표협동조합'):
        df_loc.loc[i, '사용장소'] = '작은따옴표'
        
    elif (df_loc.loc[i, '사용장소']=='커피빈') or (df_loc.loc[i, '사용장소']=='커피빈코리아인'):
        df_loc.loc[i, '사용장소'] = '커피빈코리아'
        
    elif (df_loc.loc[i, '사용장소']=='콩심 서울대점') or (df_loc.loc[i, '사용장소']=='콩심서울대점'):
        df_loc.loc[i, '사용장소'] = '콩심'
        
        
    
    elif df_loc.loc[i, '사용장소']=='종로계림닭도리탕':
        df_loc.loc[i, '사용장소'] = '종로계림닭도리탕원조'
        
    elif df_loc.loc[i, '사용장소']=='진부령　황태촌':
        df_loc.loc[i, '사용장소'] = '진부령황태촌'    
    
    elif df_loc.loc[i, '사용장소']=='진우리참치':
        df_loc.loc[i, '사용장소'] = '진우리독도참치'    
        
    elif df_loc.loc[i, '사용장소']=='카페모아관악구청점':
        df_loc.loc[i, '사용장소'] = '카페모아'    
    
    elif df_loc.loc[i, '사용장소']=='쿠팡㈜':
        df_loc.loc[i, '사용장소'] = '쿠팡'       
    
    elif df_loc.loc[i, '사용장소']=='태창약국':
        df_loc.loc[i, '사용장소'] = '태창온누리약국'     
    
    elif df_loc.loc[i, '사용장소']=='투썸플레이스':
        df_loc.loc[i, '사용장소'] = '투썸서울대입구역'       
        
        
    elif (df_loc.loc[i, '사용장소']=='난곡문성파리바게뜨') or (df_loc.loc[i, '사용장소']=='난곡사거리 파리바게뜨'):
        df_loc.loc[i, '사용장소'] = '파리바게뜨'
    
    elif (df_loc.loc[i, '사용장소']=='서울대 파리바게뜨') or (df_loc.loc[i, '사용장소']=='서울대입구역2호 파리바게뜨'):
        df_loc.loc[i, '사용장소'] = '파리바게뜨'
    elif (df_loc.loc[i, '사용장소']=='은천길입구 파리바게뜨') or (df_loc.loc[i, '사용장소']=='파리바게뜨서울대입구'):
        df_loc.loc[i, '사용장소'] = '파리바게뜨'
    elif (df_loc.loc[i, '사용장소']=='파리바게트'):
        df_loc.loc[i, '사용장소'] = '파리바게뜨'
    
    elif (df_loc.loc[i, '사용장소']=='본죽 관악구청점') or (df_loc.loc[i, '사용장소']=='본죽&본도시락'):
        df_loc.loc[i, '사용장소'] = '본죽'
    elif (df_loc.loc[i, '사용장소']=='본죽&비빔밥') or (df_loc.loc[i, '사용장소']=='본죽봉천점'):
        df_loc.loc[i, '사용장소'] = '본죽'   
    elif (df_loc.loc[i, '사용장소']=='본죽＆비빔밥') or (df_loc.loc[i, '사용장소']=='본죽＆비빔밥ｃａｆｅ'):
        df_loc.loc[i, '사용장소'] = '본죽'
          
          
    elif (df_loc.loc[i, '사용장소']=='서울대학교생협호암교수회관') or (df_loc.loc[i, '사용장소']=='서울대학교생활협동조'):
        df_loc.loc[i, '사용장소'] = '서울대학교'
          
          
    elif (df_loc.loc[i, '사용장소']=='스타벅스 서울대입구역점'):
        df_loc.loc[i, '사용장소'] = '스타벅스'
    
    elif (df_loc.loc[i, '사용장소']=='아웃백') or (df_loc.loc[i, '사용장소']=='아웃백스테이크'):
        df_loc.loc[i, '사용장소'] = '아웃백스테이크하우스'
    
    elif (df_loc.loc[i, '사용장소']=='삼백돈'):
        df_loc.loc[i, '사용장소'] = '삼백돈돈가츠'      
    elif (df_loc.loc[i, '사용장소']=='두부이야기봉천점'):
        df_loc.loc[i, '사용장소'] = '두부이야기'
    elif (df_loc.loc[i, '사용장소']=='얼큰수제비') or (df_loc.loc[i, '사용장소']=='얼큰수제비 해물칼국수'):
        df_loc.loc[i, '사용장소'] = '얼큰수제비해물칼국수'
        
    elif (df_loc.loc[i, '사용장소']=='얼큰수제비') or (df_loc.loc[i, '사용장소']=='얼큰수제비 해물칼국수'):
        df_loc.loc[i, '사용장소'] = '얼큰수제비해물칼국수'
    elif (df_loc.loc[i, '사용장소']=='풍년오리'):
        df_loc.loc[i, '사용장소'] = '풍년옥'

# %%
# 중복 데이터 삭제
df_loc.drop_duplicates(['사용장소'], inplace=True)
df_loc.index = range(len(df_loc))
df_loc
# Out:
#            사용장소                               주소     사용금액        lat  \
# 0          #207              서울 관악구 원신길 128 #207    27200  37.506248
# 1      (주)소명생고기         서울 금천구 시흥대로 264 (주)소명생고기   100000  37.457203
# 2     (주)송원마포갈비    서울 영등포구 도림로147길 2-1 (주)송원마포갈비    45500  37.516644
# 3    (주)신세계페이먼츠      서울 중구 남대문시장10길 2 (주)신세계페이먼츠   546290  37.560333
# 4     (주)신화아이푸드  충청북도 청주시 서원구 1순환로 886 (주)신화아이푸드   469500  36.616615
# ..          ...                              ...      ...        ...
# 544        흥부보쌈         서울 관악구 신림로59길 15-13 흥부보쌈  1167000  37.482655
# 545        희로애락              서울 관악구 봉천로 465 희로애락   508000  37.482469
# 546        희전명가          서울 관악구 남부순환로180길 6 희전명가    88000  37.485211
# 547        히포커피            서울 관악구 신림로23길 21 히포커피    10800  37.469969
# 548         Ｇ마켓                   서울 강남구 역삼동 Ｇ마켓    76000  37.499971
#
#             lng             거리
# 0    126.913952    4559.495385
# 1    126.899928    5111.949204
# 2    126.889236    6969.211685
# 3    126.982963    9555.694239
# 4    127.469836  106263.797527
# ..          ...            ...
# 544  126.929366    2019.981634
# 545  126.951614     486.587335
# 546  126.931504    1935.672971
# 547  126.934968    1717.771051
# 548  127.036481    7880.609105
#
# [549 rows x 6 columns]

# %%
for i in tqdm(df_cate.index):
    for j in tqdm(df_loc.index):
        if df_cate.loc[i, '사용장소']==df_loc.loc[j, '사용장소']:
            df_cate.loc[i, '주소'] = df_loc.loc[j, '주소']
            df_cate.loc[i, 'lat'] = df_loc.loc[j, 'lat']
            df_cate.loc[i, 'lng'] = df_loc.loc[j, 'lng']
# Out:
#   0%|                                                                                          | 0/119 [00:00<?, ?it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 18990.49it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20396.95it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 18351.79it/s]
#   3%|██                                                                                | 3/119 [00:00<00:03, 29.49it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22928.14it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 23917.91it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 26212.31it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 19657.44it/s]
#   6%|████▊                                                                             | 7/119 [00:00<00:03, 31.14it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 23930.84it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 18978.13it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21171.67it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28969.90it/s]
#   9%|███████▍                                                                         | 11/119 [00:00<00:03, 31.00it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 17756.71it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20386.30it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 19575.23it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 19659.46it/s]
#  13%|██████████▏                                                                      | 15/119 [00:00<00:03, 30.26it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 15290.70it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 17203.77it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22017.66it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20375.47it/s]
#  16%|████████████▉                                                                    | 19/119 [00:00<00:03, 29.21it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 18981.88it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21166.61it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 23934.32it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21171.28it/s]
#  19%|███████████████▋                                                                 | 23/119 [00:00<00:03, 29.49it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 18348.58it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22935.90it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 27525.50it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22924.71it/s]
#  23%|██████████████████▍                                                              | 27/119 [00:00<00:03, 30.60it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 18980.94it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21189.40it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 19658.11it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22935.22it/s]
#  26%|█████████████████████                                                            | 31/119 [00:01<00:02, 30.53it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 15290.91it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20386.66it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 17201.33it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22017.87it/s]
#  29%|███████████████████████▊                                                         | 35/119 [00:01<00:02, 29.16it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34404.71it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 26224.25it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28972.09it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 25022.25it/s]
#  33%|██████████████████████████▌                                                      | 39/119 [00:01<00:02, 31.47it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22017.45it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 19659.29it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21174.20it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22011.56it/s]
#  36%|█████████████████████████████▎                                                   | 43/119 [00:01<00:02, 31.28it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22018.29it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 18981.57it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21172.64it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28975.37it/s]
#  39%|███████████████████████████████▉                                                 | 47/119 [00:01<00:02, 31.07it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28208.31it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34402.14it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 32350.00it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 25020.89it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 29027.97it/s]
#  44%|███████████████████████████████████▍                                             | 52/119 [00:01<00:01, 34.36it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 27530.76it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34404.71it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28949.87it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34405.74it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34401.63it/s]
#  48%|██████████████████████████████████████▊                                          | 57/119 [00:01<00:01, 36.92it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22935.22it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30616.58it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 23934.32it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22936.13it/s]
#  51%|█████████████████████████████████████████▌                                       | 61/119 [00:01<00:01, 37.55it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22934.53it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28970.27it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20657.70it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30586.48it/s]
#  55%|████████████████████████████████████████████▏                                    | 65/119 [00:01<00:01, 37.27it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 26223.06it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30583.64it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 32471.80it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34405.74it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 26213.50it/s]
#  59%|███████████████████████████████████████████████▋                                 | 70/119 [00:02<00:01, 37.61it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30583.64it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 24725.36it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 26215.00it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 25021.98it/s]
#  62%|██████████████████████████████████████████████████▎                              | 74/119 [00:02<00:01, 37.94it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 23933.82it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22935.45it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 26214.10it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28971.00it/s]
#  66%|█████████████████████████████████████████████████████                            | 78/119 [00:02<00:01, 35.89it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 27541.96it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30582.02it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22019.13it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 25021.71it/s]
#  69%|███████████████████████████████████████████████████████▊                         | 82/119 [00:02<00:01, 34.88it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30584.05it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20388.46it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30581.20it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 25026.88it/s]
#  72%|██████████████████████████████████████████████████████████▌                      | 86/119 [00:02<00:01, 32.80it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28998.36it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28973.91it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22018.50it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28975.01it/s]
#  76%|█████████████████████████████████████████████████████████████▎                   | 90/119 [00:02<00:00, 33.96it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21182.77it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22934.53it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20387.92it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 36700.66it/s]
#  79%|███████████████████████████████████████████████████████████████▉                 | 94/119 [00:02<00:00, 34.58it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21172.06it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 27522.21it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28993.98it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 17757.54it/s]
#  82%|██████████████████████████████████████████████████████████████████▋              | 98/119 [00:02<00:00, 34.49it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28971.73it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30582.02it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 32384.12it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21164.86it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 39295.43it/s]
#  87%|█████████████████████████████████████████████████████████████████████▏          | 103/119 [00:03<00:00, 37.18it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30582.02it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34403.17it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30579.99it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 34405.22it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 20767.81it/s]
#  91%|████████████████████████████████████████████████████████████████████████▌       | 108/119 [00:03<00:00, 38.73it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 32379.57it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 32381.84it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 22020.19it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 19665.67it/s]
#  94%|███████████████████████████████████████████████████████████████████████████▎    | 112/119 [00:03<00:00, 38.08it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 21158.83it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 23932.58it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28972.46it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30584.86it/s]
#  97%|█████████████████████████████████████████████████████████████████████████████▉  | 116/119 [00:03<00:00, 37.12it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 28974.28it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 30580.39it/s]
#
# 100%|█████████████████████████████████████████████████████████████████████████████| 549/549 [00:00<00:00, 39318.91it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 119/119 [00:03<00:00, 34.36it/s]

# %%
df_cate
# Out:
#            사용장소  방문횟수     사용금액 카테고리                           주소        lat  \
# 0           가마솥     4   224000  보양식         서울 관악구 관악로17길 13 가마솥  37.480721
# 1          감나무집    33  6527500   한식        서울 관악구 관악로11길 20 감나무집  37.477906
# 2          강강술래    21  5068500   고기       서울 관악구 남부순환로 1660 강강술래  37.484604
# 3    강촌민물매운탕2호점     7   547000   해물  서울 동작구 보라매로5길 15 강촌민물매운탕2호점  37.498098
# 4           갯바위     6   458000   해물      서울 관악구 남부순환로216길 13 갯바위  37.480840
# ..          ...   ...      ...  ...                          ...        ...
# 114        해물나라    17  1892000   해물       서울 관악구 남부순환로 1674 해물나라  37.469685
# 115        홍콩반점     7   278500   중식          서울 관악구 관악로 152 홍콩반점  37.478742
# 116          황복     6   390000  보양식            서울 관악구 봉천로 356 황복  37.483903
# 117         후포리     4   535000   해물           서울 관악구 봉천로 388 후포리  37.482873
# 118        흥부보쌈     8  1167000   고기     서울 관악구 신림로59길 15-13 흥부보쌈  37.482655
#
#             lng
# 0    126.951002
# 1    126.951002
# 2    126.935058
# 3    126.920755
# 4    126.949110
# ..          ...
# 114  126.933227
# 115  126.952557
# 116  126.939363
# 117  126.943077
# 118  126.929366
#
# [119 rows x 7 columns]

# %%
df_cate.isnull().sum()
# Out:
# 사용장소    0
# 방문횟수    0
# 사용금액    0
# 카테고리    0
# 주소      1
# lat     1
# lng     1
# dtype: int64

# %%
df_cate[df_cate['주소'].isnull()]
# Out:
#      사용장소  방문횟수    사용금액 카테고리   주소  lat  lng
# 84  장수삼계탕     6  180000  보양식  NaN  NaN  NaN

# %%
# 장수삼계탕
df_cate.loc[84, ['주소', 'lat', 'lng']] ='서울특별시 관악구 봉천동 봉천로 486 장수삼계탕', 37.48199329778763, 126.9536346388275

# %%
df_cate.isnull().sum()
# Out:
# 사용장소    0
# 방문횟수    0
# 사용금액    0
# 카테고리    0
# 주소      0
# lat     0
# lng     0
# dtype: int64

# %%
df_cate[df_cate['사용장소']=='장수삼계탕']
# Out:
#      사용장소  방문횟수    사용금액 카테고리                           주소        lat  \
# 84  장수삼계탕     6  180000  보양식  서울특별시 관악구 봉천동 봉천로 486 장수삼계탕  37.481993
#
#            lng
# 84  126.953635

# %% [markdown]
# ### 데이터 저장하기

# %%
# df_cate.to_csv('./dataset/업무추진비_지도.csv', index=False)
