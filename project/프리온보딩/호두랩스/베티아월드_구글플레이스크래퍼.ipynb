# %% [markdown]
# # 구글 플레이 스크래퍼 사용하기

# %%
import pandas as pd

import requests
from bs4 import BeautifulSoup
from selenium import webdriver

# %%
data = pd.DataFrame(data=[], columns=['앱이름','아이디','리뷰','별점','날짜'])

# %%
from google_play_scraper import app

# %%
app
# Out:
# <function google_play_scraper.features.app.app(app_id: str, lang: str = 'en', country: str = 'us') -> Dict[str, Any]>

# %%
result = app(
    app_id='com.hodoolabs.betiaenglish',
    lang='en', # defaults to 'en'
    country='us' # defaults to 'us'
)

# %%
result
# Out:
# {'title': '호두잉글리시 - 베티아 월드',
#  'description': '1. 현실처럼 반영된 가상 캠퍼스!\r\n호두잉글리시의 베티아 캠퍼스에는\r\n실생활에서 만날 수 있는 다양한 상황이\r\n준비되어 있어요.\r\n학교, 식당, 가게 등의 상황 속 캐릭터와\r\n자유롭게 대화하며 영어의 자신감을 키워보세요!\r\n\r\n2. 나만의 랜드마크로 채우는 세상\r\n게임을 하면서 모은 포인트로 월드맵을 꾸밀 수 있어요.\r\n건물도 짓고 나무도 심으면서 다른 친구들이 부러워할\r\n나만의 베티아를 완성시켜 보세요!\r\n\r\n3. 퀴즈는 전투! 영어로 싸우고 더 강해지세요!\r\n베티아 주민들은 몬스터에게 청크의 기억을 빼앗기고 있습니다.\r\n5단계의 퀴즈를 모두 맞혀 몬스터를 무찔러주세요!\r\n\r\n4. 캐릭터는 또 다른 나! 자유롭게 꾸미는 아바타!\r\n베티아를 여행할 캐릭터가 항상 똑같은 모습이면 심심하겠죠?\r\n옷도 입혀보고 헤어스타일도 바꾸다보면\r\n나만의 개성이 담긴 캐릭터 완성!\r\n----\r\n개발자 연락처 :\r\n학습지원센터 1600-2176\r\n사업자 등록 번호 431-88-01287\r\n통신판매 신고 번호  2019-서울강남-00301 호',
# ...

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.hodoolabs.betiaenglish',
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    count=3, # defaults to 100
    filter_score_with=5 # defaults to None(means all score)
)

# %%
result, _ = reviews(
    'com.hodoolabs.betiaenglish',
    continuation_token=continuation_token # defaults to None(load from the beginning)
)

# %%
result
# Out:
# []

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    '',
    sleep_milliseconds=100, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

# %%
result
# Out:
# []

# %% [markdown]
# ### 한국에서 베티아 잉글리시 앱 리뷰 가져오기

# %%
from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'com.hodoolabs.betiaenglish',
    sleep_milliseconds=0, # defaults to 0
    lang='ko', # defaults to 'en'
    country='kr', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=None # defaults to None(means all score)
)

# %%
result
# Out:
# [{'reviewId': 'gp:AOqpTOHYqA5BOPpcGq9GphG7D3tv-CF7EpUsWXn-bU2kEYfJMWE9LZTgZl638jp4MCljdjKiEc93GsMuNqlW',
#   'userName': '반혜영',
#   'userImage': 'https://play-lh.googleusercontent.com/a/AATXAJy2bJc4yry64DbMOy31-MkRL3yvC8qZLFRLiI9_=mo',
#   'content': '업데이트 하라고 해서 했는데 자꾸 업데이트 하라고 나오고 앱스토어에는 이미 되어있다고 표시되네요 제거하고 새로 깔아도 계속 안되요',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.2.2',
#   'at': datetime.datetime(2022, 2, 10, 20, 2, 53),
#   'replyContent': '안녕하세요. 호두랩스입니다. 구글플레이스토어의 캐시 데이터가 베티아잉글리시 앱의 업데이트를 인지하지 못해 발생한 문제인것 같아요! 구글플레이스토어의 정보가 갱신되길 기다리는 방법도 있지만, 좀 더 빠르게 해결하는 방법을 안내하여드릴께요.\n다음의 방법을 순차적으로 따라해주시면 대부분 해결 가능합니다.\n1. [ 안드로이드 설정 - 애플리케이션 ] 으로 이동\n2. [ Google Play 스토어 - 저장공간 - 캐시삭제 ] 수행\n3. 모바일기기를 완전히 껐다 다시 켜기.',
#   'repliedAt': datetime.datetime(2022, 2, 11, 10, 6, 22)},
#  {'reviewId': 'gp:AOqpTOHJHB0vSpX8K3w4UTbXA4bcrArN_zJfhyl7igXdr8s78UttNOBgEXi_W_38jqvarGNT0aUtqrDu2qy8',
#   'userName': 'Jessica Cha',
# ...

# %%
len(result)
# Out:
# 292

# %% [markdown]
# + 292개만 가져옴
